# %% [markdown]
# ### 정책 반복 vs 가치 반복

# %% [markdown]
# `정책반복`은 정책에 따라 목표에 빠르게 도달했던 경우에 수행했던 `action`을 중요한 것으로 보고, 이 때의 행동을 앞으로도 취할 수 있도록 정책을 수정하는 방법이다. 결과가 좋았던 경우에 취했던 행동을 중시한다.<br>
# `가치반복`은 목표 지점부터 거슬러 올라가며 목표 지점과 가까운 상태로 에이전트를 유도해오는 방법이다. 목표 지점 외의 지점에도 가치를 부여한다.

# %% [markdown]
# ### policy gradient 알고리즘 따라 agent 이동

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
theta_0 = np.array([[np.nan, 1, 1, np.nan],
                   [np.nan, 1, np.nan, 1],
                   [np.nan, np.nan, 1, 1],
                   [1, 1, 1, np.nan],
                   [np.nan, np.nan, 1, 1],
                   [1, np.nan, np.nan, np.nan],
                   [1, np.nan, np.nan, np.nan],
                   [1, 1, np.nan, np.nan]]) #s8은 목표 지점이라 정책이 없다

# %%
# 앞에서는 비율 -> softmax로

def softmax_convert(theta):
    beta = 1.0
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    
    exp_theta = np.exp(beta*theta)
    
    for i in range(0, m):
        pi[i, :] = exp_theta[i,:]/ np.nansum(exp_theta[i,:])
        
    pi = np.nan_to_num(pi)
    
    return pi

# %%
# 초기 정책 pi_0 계산
pi_0 = softmax_convert(theta_0)
print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %% [markdown]
# 초기 상태는 비율과 softmax 값이 동일하지만, 하다 보면 달라질 것이다

# %%
# 행동 a와 1단계 이동 후의 상태 s 계산

def get_action_and_next_s(pi, s):
    direction = ['up', 'right', 'down','left']
    next_direct = np.random.choice(direction, p=pi[s,:])
    
    if next_direct == 'up':
        action = 0
        s_next = s - 3
    elif next_direct == 'right':
        action = 1
        s_next = s + 1
    elif next_direct == 'down':
        action = 2
        s_next = s + 3
    elif next_direct == 'left':
        action = 3
        s_next = s - 1
    
    return [action, s_next]

# %%
# 미로를 빠져나오는 함수
# 목표 지점에 이를 때까지 에이전트를 이동

def goal_sa(pi):
    s = 0
    s_a_history = [[0, np.nan]]
    
    while True:
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        s_a_history.append([next_s, np.nan])
        
        if next_s == 8 :
            break
        else:
            s = next_s
    
    return s_a_history

# %%
# 초기 정책으로 미로 빠져나오기
s_a_history = goal_sa(pi_0)
print(s_a_history)
print("걸린 단계 수 : " + str(len(s_a_history)-1))
# Out:
# [[0, 1], [1, 3], [0, 2], [3, 1], [4, 2], [7, 0], [4, 2], [7, 0], [4, 2], [7, 1], [8, nan]]
# 걸린 단계 수 : 10

# %% [markdown]
# ### 정책경사 알고리즘으로
# - 정책경사 알고리즘
# ![image.png](attachment:image.png)

# %%
# theta 수정
def update_theta(theta, pi, s_a_history):
    lr = 0.1
    T = len(s_a_history)-1
    [m,n] = theta.shape
    delta_theta = theta.copy() # theta의 변화량을 구하는 세팅
                               ### 포인터 참조이므로 delta_theta = theta는 안된다.
    # delta_theta를 요소 단위로 계산
    for i in range(0, m):
        for j in range(0, n):
            if not(np.isnan([theta[i,j]])):
                SA_i = [SA for SA in s_a_history if SA[0] == i]
                SA_ij = [SA for SA in s_a_history if SA == [i,j]]
                N_i = len(SA_i)
                N_ij = len(SA_ij)
                
                delta_theta[i, j] = (N_ij - pi[i,j]*N_i)/T
        
    new_theta = theta + lr*delta_theta
    return new_theta

# %%
# 정책 수정
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert(new_theta)
print(pi)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.49750002 0.         0.50249998]
#  [0.         0.         0.5        0.5       ]
#  [0.33222038 0.33555925 0.33222038 0.        ]
#  [0.         0.         0.50749944 0.49250056]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.50249998 0.49750002 0.         0.        ]]

# %%
# 정책 경사 알고리즘으로 미로 빠져나오기
stop_epsilon = 10**(-4)
theta = theta_0
pi = pi_0
is_countinue = True

while is_countinue:
    s_a_history = goal_sa(pi)
    new_theta = update_theta(theta, pi, s_a_history)
    new_pi = softmax_convert(new_theta)
    
    print(np.sum(np.abs(new_pi-pi)))
    print("목표 지점까지 걸린 단계 수 : " + str(len(s_a_history)-1))
    
    if np.sum(np.abs(new_pi-pi)) < stop_epsilon:
        is_countinue = False
    else :
        theta = new_theta
        pi = new_pi
# Out:
# 0.01565802335414984
# 목표 지점까지 걸린 단계 수 : 22
# 0.014185496874169035
# 목표 지점까지 걸린 단계 수 : 36
# 0.016720351113403253
# 목표 지점까지 걸린 단계 수 : 12
# 0.01770608500517379
# 목표 지점까지 걸린 단계 수 : 18
# 0.013739120808793082
# 목표 지점까지 걸린 단계 수 : 28
# 0.013149268350540866
# 목표 지점까지 걸린 단계 수 : 38
# 0.015862997586469474
# 목표 지점까지 걸린 단계 수 : 26
# 0.01637694397165307
# 목표 지점까지 걸린 단계 수 : 40
# 0.012459365439103087
# 목표 지점까지 걸린 단계 수 : 44
# 0.008118425501549287
# 목표 지점까지 걸린 단계 수 : 84
# 0.013733803522789523
# 목표 지점까지 걸린 단계 수 : 40
# 0.011710931082864362
# 목표 지점까지 걸린 단계 수 : 78
# 0.016650636024018395
# 목표 지점까지 걸린 단계 수 : 44
# 0.008689738865103824
# 목표 지점까지 걸린 단계 수 : 86
# 0.008461973992030192
# 목표 지점까지 걸린 단계 수 : 52
# 0.019509764572115285
# 목표 지점까지 걸린 단계 수 : 18
# 0.021189112906182916
# 목표 지점까지 걸린 단계 수 : 20
# 0.013742543071151303
# 목표 지점까지 걸린 단계 수 : 38
# 0.024710252682835776
# 목표 지점까지 걸린 단계 수 : 8
# 0.025024757305630252
# 목표 지점까지 걸린 단계 수 : 10
# 0.017286569529291085
# 목표 지점까지 걸린 단계 수 : 12
# 0.02027007280523646
# 목표 지점까지 걸린 단계 수 : 8
# 0.025482012621545647
# 목표 지점까지 걸린 단계 수 : 10
# 0.01999298972557917
# 목표 지점까지 걸린 단계 수 : 18
# 0.010647670931327236
# 목표 지점까지 걸린 단계 수 : 34
# 0.024359002667211527
# 목표 지점까지 걸린 단계 수 : 8
# 0.013329587365986939
# 목표 지점까지 걸린 단계 수 : 44
# 0.009906350370258943
# 목표 지점까지 걸린 단계 수 : 16
# 0.04697227570870155
# 목표 지점까지 걸린 단계 수 : 4
# 0.00884299534575611
# 목표 지점까지 걸린 단계 수 : 96
# 0.03678503460295973
# 목표 지점까지 걸린 단계 수 : 8
# 0.046247227301424165
# 목표 지점까지 걸린 단계 수 : 4
# 0.005693822500745294
# 목표 지점까지 걸린 단계 수 : 92
# 0.005868273331767926
# 목표 지점까지 걸린 단계 수 : 124
# 0.020461978504312084
# 목표 지점까지 걸린 단계 수 : 16
# 0.013645874400384617
# 목표 지점까지 걸린 단계 수 : 32
# 0.013995640101855278
# 목표 지점까지 걸린 단계 수 : 26
# 0.014004542975001755
# 목표 지점까지 걸린 단계 수 : 22
# 0.015366351540499867
# 목표 지점까지 걸린 단계 수 : 10
# 0.008666837755731793
# 목표 지점까지 걸린 단계 수 : 114
# 0.009862825539144804
# 목표 지점까지 걸린 단계 수 : 18
# 0.01825273879597672
# 목표 지점까지 걸린 단계 수 : 12
# 0.01000520708724384
# 목표 지점까지 걸린 단계 수 : 54
# 0.01054963609927767
# 목표 지점까지 걸린 단계 수 : 54
# 0.01381301775656052
# 목표 지점까지 걸린 단계 수 : 28
# 0.011122391534672593
# 목표 지점까지 걸린 단계 수 : 40
# 0.029464226095156254
# 목표 지점까지 걸린 단계 수 : 6
# 0.010397950419567814
# 목표 지점까지 걸린 단계 수 : 32
# 0.008764594183175878
# 목표 지점까지 걸린 단계 수 : 108
# 0.04532413321681655
# 목표 지점까지 걸린 단계 수 : 4
# 0.022652060296914023
# 목표 지점까지 걸린 단계 수 : 18
# 0.009043773818947332
# 목표 지점까지 걸린 단계 수 : 124
# 0.009638100778275482
# 목표 지점까지 걸린 단계 수 : 96
# 0.015695479275374957
# 목표 지점까지 걸린 단계 수 : 12
# 0.006588653143089818
# 목표 지점까지 걸린 단계 수 : 62
# 0.010499539330515617
# 목표 지점까지 걸린 단계 수 : 90
# 0.014266244178412046
# 목표 지점까지 걸린 단계 수 : 28
# 0.010115445497750675
# 목표 지점까지 걸린 단계 수 : 52
# 0.014489184992619475
# 목표 지점까지 걸린 단계 수 : 14
# 0.011053159534830048
# 목표 지점까지 걸린 단계 수 : 52
# 0.013657136086337396
# 목표 지점까지 걸린 단계 수 : 42
# 0.014378579669623415
# 목표 지점까지 걸린 단계 수 : 98
# 0.01211769566934967
# 목표 지점까지 걸린 단계 수 : 36
# 0.018709360964066113
# 목표 지점까지 걸린 단계 수 : 26
# 0.013969310381874711
# 목표 지점까지 걸린 단계 수 : 12
# 0.007255450879224357
# 목표 지점까지 걸린 단계 수 : 34
# 0.02351607833212399
# 목표 지점까지 걸린 단계 수 : 8
# 0.010470055208911089
# 목표 지점까지 걸린 단계 수 : 42
# 0.006704483592640587
# 목표 지점까지 걸린 단계 수 : 54
# 0.013282114265343703
# 목표 지점까지 걸린 단계 수 : 24
# 0.012829300404198718
# 목표 지점까지 걸린 단계 수 : 50
# 0.016334087299901157
# 목표 지점까지 걸린 단계 수 : 18
# 0.02507993878609044
# 목표 지점까지 걸린 단계 수 : 8
# 0.011292348090506943
# 목표 지점까지 걸린 단계 수 : 20
# 0.028415377845765977
# 목표 지점까지 걸린 단계 수 : 6
# 0.011741512497097761
# 목표 지점까지 걸린 단계 수 : 36
# 0.02690617444895288
# 목표 지점까지 걸린 단계 수 : 16
# 0.01559467582826296
# 목표 지점까지 걸린 단계 수 : 16
# 0.035630483766386334
# 목표 지점까지 걸린 단계 수 : 8
# 0.01328889441040848
# 목표 지점까지 걸린 단계 수 : 18
# 0.016160538960626303
# 목표 지점까지 걸린 단계 수 : 18
# 0.014889932250709281
# 목표 지점까지 걸린 단계 수 : 38
# 0.023019011493068064
# 목표 지점까지 걸린 단계 수 : 20
# 0.008792171038664143
# 목표 지점까지 걸린 단계 수 : 60
# 0.019051454938308232
# 목표 지점까지 걸린 단계 수 : 36
# 0.0064050522782834185
# 목표 지점까지 걸린 단계 수 : 54
# 0.014309155379528093
# 목표 지점까지 걸린 단계 수 : 54
# 0.043397468483207025
# 목표 지점까지 걸린 단계 수 : 4
# 0.014678624235109128
# 목표 지점까지 걸린 단계 수 : 10
# 0.018117167134794554
# 목표 지점까지 걸린 단계 수 : 14
# 0.017259559912189137
# 목표 지점까지 걸린 단계 수 : 28
# 0.01455805731348514
# 목표 지점까지 걸린 단계 수 : 18
# 0.030822036035417666
# 목표 지점까지 걸린 단계 수 : 6
# 0.01042312964373443
# 목표 지점까지 걸린 단계 수 : 24
# 0.009202138586279773
# 목표 지점까지 걸린 단계 수 : 46
# 0.012333588615828728
# 목표 지점까지 걸린 단계 수 : 92
# 0.007664160944926279
# 목표 지점까지 걸린 단계 수 : 70
# 0.00882226010952264
# 목표 지점까지 걸린 단계 수 : 28
# 0.00948281691939784
# 목표 지점까지 걸린 단계 수 : 144
# 0.03530069669469049
# 목표 지점까지 걸린 단계 수 : 8
# 0.01185527994510488
# 목표 지점까지 걸린 단계 수 : 70
# 0.02312404767286569
# 목표 지점까지 걸린 단계 수 : 14
# 0.01549023115579895
# 목표 지점까지 걸린 단계 수 : 12
# 0.012425402327573998
# 목표 지점까지 걸린 단계 수 : 26
# 0.013533243748443502
# 목표 지점까지 걸린 단계 수 : 46
# 0.012445508958939033
# 목표 지점까지 걸린 단계 수 : 36
# 0.017927026270549706
# 목표 지점까지 걸린 단계 수 : 12
# 0.012496402394720107
# 목표 지점까지 걸린 단계 수 : 28
# 0.030875285817197617
# 목표 지점까지 걸린 단계 수 : 6
# 0.013056140148193507
# 목표 지점까지 걸린 단계 수 : 60
# 0.011604841677294309
# 목표 지점까지 걸린 단계 수 : 28
# 0.04185135072132262
# 목표 지점까지 걸린 단계 수 : 4
# 0.0413223723193723
# 목표 지점까지 걸린 단계 수 : 4
# 0.010564945343429999
# 목표 지점까지 걸린 단계 수 : 70
# 0.01582313897929971
# 목표 지점까지 걸린 단계 수 : 20
# 0.011334035462695291
# 목표 지점까지 걸린 단계 수 : 22
# 0.00838859441378459
# 목표 지점까지 걸린 단계 수 : 32
# 0.012240970789782257
# 목표 지점까지 걸린 단계 수 : 16
# 0.04076848879517242
# 목표 지점까지 걸린 단계 수 : 4
# 0.013950072354590948
# 목표 지점까지 걸린 단계 수 : 54
# 0.03205648757579316
# 목표 지점까지 걸린 단계 수 : 6
# 0.03980839131743852
# 목표 지점까지 걸린 단계 수 : 4
# 0.03928620745145911
# 목표 지점까지 걸린 단계 수 : 4
# 0.009655450704752266
# 목표 지점까지 걸린 단계 수 : 94
# 0.020901804024563264
# 목표 지점까지 걸린 단계 수 : 12
# 0.02881914795878876
# 목표 지점까지 걸린 단계 수 : 6
# 0.011880368028985455
# 목표 지점까지 걸린 단계 수 : 20
# 0.008962659226050662
# 목표 지점까지 걸린 단계 수 : 52
# 0.010897936728182844
# 목표 지점까지 걸린 단계 수 : 54
# 0.012599279143316433
# 목표 지점까지 걸린 단계 수 : 38
# 0.018268021992152106
# 목표 지점까지 걸린 단계 수 : 28
# 0.03015344579184437
# 목표 지점까지 걸린 단계 수 : 6
# 0.018349085996294645
# 목표 지점까지 걸린 단계 수 : 12
# 0.016285309147796745
# 목표 지점까지 걸린 단계 수 : 14
# 0.023443284360965266
# 목표 지점까지 걸린 단계 수 : 38
# 0.018093576129695865
# 목표 지점까지 걸린 단계 수 : 10
# 0.018098272967728313
# 목표 지점까지 걸린 단계 수 : 8
# 0.019847204347852976
# 목표 지점까지 걸린 단계 수 : 8
# 0.01832766934391422
# 목표 지점까지 걸린 단계 수 : 30
# 0.015180011819171835
# 목표 지점까지 걸린 단계 수 : 16
# 0.027675118976231983
# 목표 지점까지 걸린 단계 수 : 10
# 0.010730919563373076
# 목표 지점까지 걸린 단계 수 : 50
# 0.03761883278459893
# 목표 지점까지 걸린 단계 수 : 4
# 0.016949678330739015
# 목표 지점까지 걸린 단계 수 : 38
# 0.009324348051341858
# 목표 지점까지 걸린 단계 수 : 48
# 0.01894255223863861
# 목표 지점까지 걸린 단계 수 : 22
# 0.013275312642972992
# 목표 지점까지 걸린 단계 수 : 16
# 0.032068181347562896
# 목표 지점까지 걸린 단계 수 : 6
# 0.022757084923009596
# 목표 지점까지 걸린 단계 수 : 12
# 0.01255417432937983
# 목표 지점까지 걸린 단계 수 : 38
# 0.013734733495621487
# 목표 지점까지 걸린 단계 수 : 24
# 0.009562206476671664
# 목표 지점까지 걸린 단계 수 : 14
# 0.011803000859060886
# 목표 지점까지 걸린 단계 수 : 10
# 0.037054482668080146
# 목표 지점까지 걸린 단계 수 : 4
# 0.010601439595622875
# 목표 지점까지 걸린 단계 수 : 32
# 0.012164061446448993
# 목표 지점까지 걸린 단계 수 : 14
# 0.02304117875963485
# 목표 지점까지 걸린 단계 수 : 12
# 0.013051436379397596
# 목표 지점까지 걸린 단계 수 : 24
# 0.010075604917741066
# 목표 지점까지 걸린 단계 수 : 32
# 0.010199054434269605
# 목표 지점까지 걸린 단계 수 : 30
# 0.019747151453422318
# 목표 지점까지 걸린 단계 수 : 22
# 0.0364667711182739
# 목표 지점까지 걸린 단계 수 : 4
# 0.01868527497410466
# 목표 지점까지 걸린 단계 수 : 30
# 0.011376540522145207
# 목표 지점까지 걸린 단계 수 : 20
# 0.013183935702689498
# 목표 지점까지 걸린 단계 수 : 54
# 0.01239516466560181
# 목표 지점까지 걸린 단계 수 : 28
# 0.01542135095598729
# 목표 지점까지 걸린 단계 수 : 22
# 0.008712383409887725
# 목표 지점까지 걸린 단계 수 : 32
# 0.027362106544220943
# 목표 지점까지 걸린 단계 수 : 6
# 0.03593892381430347
# 목표 지점까지 걸린 단계 수 : 4
# 0.015274049199660411
# 목표 지점까지 걸린 단계 수 : 18
# 0.010025752389791531
# 목표 지점까지 걸린 단계 수 : 22
# 0.020620122034684774
# 목표 지점까지 걸린 단계 수 : 12
# 0.017921634403579578
# 목표 지점까지 걸린 단계 수 : 34
# 0.013343300400825153
# 목표 지점까지 걸린 단계 수 : 12
# 0.015183638277683986
# 목표 지점까지 걸린 단계 수 : 38
# 0.01920313482688263
# 목표 지점까지 걸린 단계 수 : 8
# 0.014753107953804911
# 목표 지점까지 걸린 단계 수 : 24
# 0.020333308654652604
# 목표 지점까지 걸린 단계 수 : 22
# 0.011068016952737514
# 목표 지점까지 걸린 단계 수 : 10
# 0.01333208250239315
# 목표 지점까지 걸린 단계 수 : 36
# 0.010376940984143934
# 목표 지점까지 걸린 단계 수 : 38
# 0.03536828447139123
# 목표 지점까지 걸린 단계 수 : 4
# 0.02058185160274173
# 목표 지점까지 걸린 단계 수 : 20
# 0.010512193857235341
# 목표 지점까지 걸린 단계 수 : 18
# 0.02498770904914821
# 목표 지점까지 걸린 단계 수 : 16
# 0.02272531846873338
# 목표 지점까지 걸린 단계 수 : 18
# 0.017282202268005975
# 목표 지점까지 걸린 단계 수 : 26
# 0.01210117141485545
# 목표 지점까지 걸린 단계 수 : 60
# 0.027996666004049653
# 목표 지점까지 걸린 단계 수 : 8
# 0.021739720257022144
# 목표 지점까지 걸린 단계 수 : 6
# 0.03165435983091114
# 목표 지점까지 걸린 단계 수 : 6
# 0.013143150709848395
# 목표 지점까지 걸린 단계 수 : 36
# 0.015232333140391907
# 목표 지점까지 걸린 단계 수 : 24
# 0.01656180598392798
# 목표 지점까지 걸린 단계 수 : 12
# 0.013460931728968561
# 목표 지점까지 걸린 단계 수 : 48
# 0.02083367478783882
# 목표 지점까지 걸린 단계 수 : 16
# 0.026425869966115123
# 목표 지점까지 걸린 단계 수 : 6
# 0.02625273107173043
# 목표 지점까지 걸린 단계 수 : 6
# 0.011495215422422322
# 목표 지점까지 걸린 단계 수 : 26
# 0.02275284575523645
# 목표 지점까지 걸린 단계 수 : 12
# 0.01753978141504109
# 목표 지점까지 걸린 단계 수 : 18
# 0.02587817927965458
# 목표 지점까지 걸린 단계 수 : 6
# 0.034080339590266795
# 목표 지점까지 걸린 단계 수 : 4
# 0.030229005396586683
# 목표 지점까지 걸린 단계 수 : 12
# 0.02814044561003559
# 목표 지점까지 걸린 단계 수 : 6
# 0.02020068449655632
# 목표 지점까지 걸린 단계 수 : 20
# 0.010631212962008585
# 목표 지점까지 걸린 단계 수 : 64
# 0.02794921177926951
# 목표 지점까지 걸린 단계 수 : 6
# 0.01799918749507945
# 목표 지점까지 걸린 단계 수 : 18
# 0.03321359664511386
# 목표 지점까지 걸린 단계 수 : 4
# 0.007237105653185971
# 목표 지점까지 걸린 단계 수 : 38
# 0.030740279283164418
# 목표 지점까지 걸린 단계 수 : 6
# 0.018618770510499927
# 목표 지점까지 걸린 단계 수 : 50
# 0.018336666379088706
# 목표 지점까지 걸린 단계 수 : 8
# 0.030510943566847415
# 목표 지점까지 걸린 단계 수 : 8
# 0.025873958783008022
# 목표 지점까지 걸린 단계 수 : 12
# 0.03639879417907299
# 목표 지점까지 걸린 단계 수 : 10
# 0.016395477061517894
# 목표 지점까지 걸린 단계 수 : 28
# 0.03194725859155059
# 목표 지점까지 걸린 단계 수 : 10
# 0.02424553847191771
# 목표 지점까지 걸린 단계 수 : 12
# 0.03010206423033268
# 목표 지점까지 걸린 단계 수 : 8
# 0.02281064738367239
# 목표 지점까지 걸린 단계 수 : 20
# 0.014063342105636534
# 목표 지점까지 걸린 단계 수 : 26
# 0.015051951841658251
# 목표 지점까지 걸린 단계 수 : 10
# 0.02722624294472556
# 목표 지점까지 걸린 단계 수 : 12
# 0.022544186472783945
# 목표 지점까지 걸린 단계 수 : 18
# 0.017021070115128017
# 목표 지점까지 걸린 단계 수 : 8
# 0.022057383723244867
# 목표 지점까지 걸린 단계 수 : 26
# 0.03259972692864879
# 목표 지점까지 걸린 단계 수 : 4
# 0.023713738596234768
# 목표 지점까지 걸린 단계 수 : 6
# 0.023353229614579862
# 목표 지점까지 걸린 단계 수 : 6
# 0.01893524425212406
# 목표 지점까지 걸린 단계 수 : 10
# 0.024234739019386886
# 목표 지점까지 걸린 단계 수 : 6
# 0.031179667106228798
# 목표 지점까지 걸린 단계 수 : 4
# 0.010347826060411541
# 목표 지점까지 걸린 단계 수 : 14
# 0.014715805974363977
# 목표 지점까지 걸린 단계 수 : 34
# 0.019834054120222128
# 목표 지점까지 걸린 단계 수 : 14
# 0.02185964522330991
# 목표 지점까지 걸린 단계 수 : 14
# 0.0056907506078291425
# 목표 지점까지 걸린 단계 수 : 14
# 0.012945719466364303
# 목표 지점까지 걸린 단계 수 : 16
# 0.030308419660083658
# 목표 지점까지 걸린 단계 수 : 10
# 0.01724713711048867
# 목표 지점까지 걸린 단계 수 : 22
# 0.01840875723212282
# 목표 지점까지 걸린 단계 수 : 10
# 0.018589897771581848
# 목표 지점까지 걸린 단계 수 : 16
# 0.03103416686486804
# 목표 지점까지 걸린 단계 수 : 4
# 0.011457645540311256
# 목표 지점까지 걸린 단계 수 : 26
# 0.009850074298703965
# 목표 지점까지 걸린 단계 수 : 12
# 0.016721926658000708
# 목표 지점까지 걸린 단계 수 : 8
# 0.030604973149736425
# 목표 지점까지 걸린 단계 수 : 4
# 0.018277086817164917
# 목표 지점까지 걸린 단계 수 : 6
# 0.022040236383137762
# 목표 지점까지 걸린 단계 수 : 6
# 0.014881722897819888
# 목표 지점까지 걸린 단계 수 : 24
# 0.01856643746575712
# 목표 지점까지 걸린 단계 수 : 12
# 0.011183081063607353
# 목표 지점까지 걸린 단계 수 : 14
# 0.020064457056637175
# 목표 지점까지 걸린 단계 수 : 16
# 0.021554622142512997
# 목표 지점까지 걸린 단계 수 : 10
# 0.00996873306306173
# 목표 지점까지 걸린 단계 수 : 30
# 0.015155527669476476
# 목표 지점까지 걸린 단계 수 : 12
# 0.0268014213038123
# 목표 지점까지 걸린 단계 수 : 8
# 0.026540660553889928
# 목표 지점까지 걸린 단계 수 : 6
# 0.017991574250021347
# 목표 지점까지 걸린 단계 수 : 6
# 0.02618036640998697
# 목표 지점까지 걸린 단계 수 : 6
# 0.029404725976784202
# 목표 지점까지 걸린 단계 수 : 10
# 0.015329889776295264
# 목표 지점까지 걸린 단계 수 : 32
# 0.025593985095206467
# 목표 지점까지 걸린 단계 수 : 12
# 0.029189406454882133
# 목표 지점까지 걸린 단계 수 : 4
# 0.02875911480239865
# 목표 지점까지 걸린 단계 수 : 4
# 0.015105664217321957
# 목표 지점까지 걸린 단계 수 : 12
# 0.015371098164177616
# 목표 지점까지 걸린 단계 수 : 14
# 0.028306272565165297
# 목표 지점까지 걸린 단계 수 : 4
# 0.027890277717490558
# 목표 지점까지 걸린 단계 수 : 4
# 0.02748005356641159
# 목표 지점까지 걸린 단계 수 : 4
# 0.015083360598361018
# 목표 지점까지 걸린 단계 수 : 18
# 0.015774931076701693
# 목표 지점까지 걸린 단계 수 : 20
# 0.027713215003395103
# 목표 지점까지 걸린 단계 수 : 6
# 0.015707312754836722
# 목표 지점까지 걸린 단계 수 : 14
# 0.019158522617879037
# 목표 지점까지 걸린 단계 수 : 18
# 0.016166104388117608
# 목표 지점까지 걸린 단계 수 : 20
# 0.027290643941799253
# 목표 지점까지 걸린 단계 수 : 4
# 0.02035107368844924
# 목표 지점까지 걸린 단계 수 : 6
# 0.019750247005696192
# 목표 지점까지 걸린 단계 수 : 8
# 0.016706356406603312
# 목표 지점까지 걸린 단계 수 : 12
# 0.029610451370609275
# 목표 지점까지 걸린 단계 수 : 12
# 0.019773250860074087
# 목표 지점까지 걸린 단계 수 : 18
# 0.027029581282578596
# 목표 지점까지 걸린 단계 수 : 6
# 0.024682475435341966
# 목표 지점까지 걸린 단계 수 : 18
# 0.012661972487417655
# 목표 지점까지 걸린 단계 수 : 16
# 0.01918036586415192
# 목표 지점까지 걸린 단계 수 : 8
# 0.01631419992543709
# 목표 지점까지 걸린 단계 수 : 8
# 0.012046900341486616
# 목표 지점까지 걸린 단계 수 : 28
# 0.013108032332160235
# 목표 지점까지 걸린 단계 수 : 38
# 0.02714730296329465
# 목표 지점까지 걸린 단계 수 : 4
# 0.02305758827226828
# 목표 지점까지 걸린 단계 수 : 6
# 0.01534376052289918
# 목표 지점까지 걸린 단계 수 : 18
# 0.018301755381508522
# 목표 지점까지 걸린 단계 수 : 10
# 0.026664532347128594
# 목표 지점까지 걸린 단계 수 : 4
# 0.016572844638407608
# 목표 지점까지 걸린 단계 수 : 6
# 0.022155797100943286
# 목표 지점까지 걸린 단계 수 : 10
# 0.011534021528280342
# 목표 지점까지 걸린 단계 수 : 14
# 0.0329377427975735
# 목표 지점까지 걸린 단계 수 : 10
# 0.017143138221619753
# 목표 지점까지 걸린 단계 수 : 8
# 0.013492829406120205
# 목표 지점까지 걸린 단계 수 : 12
# 0.026163861888951867
# 목표 지점까지 걸린 단계 수 : 4
# 0.01341147722374511
# 목표 지점까지 걸린 단계 수 : 56
# 0.02006218738941548
# 목표 지점까지 걸린 단계 수 : 6
# 0.0105145596793349
# 목표 지점까지 걸린 단계 수 : 14
# 0.015598289433897766
# 목표 지점까지 걸린 단계 수 : 8
# 0.022933511386532907
# 목표 지점까지 걸린 단계 수 : 8
# 0.016412231010561468
# 목표 지점까지 걸린 단계 수 : 6
# 0.025442284010078503
# 목표 지점까지 걸린 단계 수 : 4
# 0.017192389643309935
# 목표 지점까지 걸린 단계 수 : 40
# 0.02520840270466665
# 목표 지점까지 걸린 단계 수 : 4
# 0.023384382753885324
# 목표 지점까지 걸린 단계 수 : 6
# 0.016019665913304976
# 목표 지점까지 걸린 단계 수 : 6
# 0.024528938480313317
# 목표 지점까지 걸린 단계 수 : 4
# 0.02085703927985974
# 목표 지점까지 걸린 단계 수 : 10
# 0.021683791946201514
# 목표 지점까지 걸린 단계 수 : 8
# 0.02140928064527048
# 목표 지점까지 걸린 단계 수 : 10
# 0.021663354034512722
# 목표 지점까지 걸린 단계 수 : 6
# 0.023878779563030694
# 목표 지점까지 걸린 단계 수 : 4
# 0.023525235628026525
# 목표 지점까지 걸린 단계 수 : 4
# 0.015411611284430776
# 목표 지점까지 걸린 단계 수 : 8
# 0.02315395999052186
# 목표 지점까지 걸린 단계 수 : 4
# 0.01277584479231103
# 목표 지점까지 걸린 단계 수 : 8
# 0.014155030405712643
# 목표 지점까지 걸린 단계 수 : 28
# 0.02296076031076974
# 목표 지점까지 걸린 단계 수 : 4
# 0.022620888133564054
# 목표 지점까지 걸린 단계 수 : 4
# 0.02228659932739055
# 목표 지점까지 걸린 단계 수 : 4
# 0.017437264654102752
# 목표 지점까지 걸린 단계 수 : 6
# 0.013548342636867106
# 목표 지점까지 걸린 단계 수 : 10
# 0.021742520563180323
# 목표 지점까지 걸린 단계 수 : 4
# 0.012489631696961684
# 목표 지점까지 걸린 단계 수 : 10
# 0.015869019511006166
# 목표 지점까지 걸린 단계 수 : 16
# 0.013722317642039211
# 목표 지점까지 걸린 단계 수 : 16
# 0.01518783948132213
# 목표 지점까지 걸린 단계 수 : 22
# 0.02483166909044804
# 목표 지점까지 걸린 단계 수 : 6
# 0.017459998130572668
# 목표 지점까지 걸린 단계 수 : 6
# 0.012907047703330177
# 목표 지점까지 걸린 단계 수 : 12
# 0.0169848459861274
# 목표 지점까지 걸린 단계 수 : 10
# 0.014634204761570985
# 목표 지점까지 걸린 단계 수 : 6
# 0.021178977018884326
# 목표 지점까지 걸린 단계 수 : 6
# 0.02142942974643494
# 목표 지점까지 걸린 단계 수 : 4
# 0.02111422194986179
# 목표 지점까지 걸린 단계 수 : 4
# 0.02080432814032948
# 목표 지점까지 걸린 단계 수 : 4
# 0.01163312083507373
# 목표 지점까지 걸린 단계 수 : 8
# 0.018435252344359332
# 목표 지점까지 걸린 단계 수 : 8
# 0.013212742086173318
# 목표 지점까지 걸린 단계 수 : 16
# 0.022597745928808588
# 목표 지점까지 걸린 단계 수 : 10
# 0.014630348670883586
# 목표 지점까지 걸린 단계 수 : 14
# 0.02717367429870096
# 목표 지점까지 걸린 단계 수 : 24
# 0.024216854819429617
# 목표 지점까지 걸린 단계 수 : 28
# 0.016960499463233247
# 목표 지점까지 걸린 단계 수 : 22
# 0.023296299422722683
# 목표 지점까지 걸린 단계 수 : 8
# 0.011646199738595042
# 목표 지점까지 걸린 단계 수 : 8
# 0.014443958884264113
# 목표 지점까지 걸린 단계 수 : 6
# 0.020912999460532655
# 목표 지점까지 걸린 단계 수 : 4
# 0.02060618123581162
# 목표 지점까지 걸린 단계 수 : 4
# 0.020304577916096855
# 목표 지점까지 걸린 단계 수 : 4
# 0.019939804932449096
# 목표 지점까지 걸린 단계 수 : 6
# 0.015593374551918615
# 목표 지점까지 걸린 단계 수 : 8
# 0.014633351939742911
# 목표 지점까지 걸린 단계 수 : 14
# 0.01998553224093841
# 목표 지점까지 걸린 단계 수 : 18
# 0.020124538293945032
# 목표 지점까지 걸린 단계 수 : 4
# 0.01367172210819112
# 목표 지점까지 걸린 단계 수 : 6
# 0.019736909939768954
# 목표 지점까지 걸린 단계 수 : 4
# 0.019858452247353803
# 목표 지점까지 걸린 단계 수 : 6
# 0.019366143634049482
# 목표 지점까지 걸린 단계 수 : 4
# 0.019575670130308115
# 목표 지점까지 걸린 단계 수 : 6
# 0.018992498910220063
# 목표 지점까지 걸린 단계 수 : 4
# 0.012792686827310995
# 목표 지점까지 걸린 단계 수 : 10
# 0.013197514768932828
# 목표 지점까지 걸린 단계 수 : 6
# 0.015141858919931667
# 목표 지점까지 걸린 단계 수 : 6
# 0.015815742732144117
# 목표 지점까지 걸린 단계 수 : 14
# 0.018511445472627286
# 목표 지점까지 걸린 단계 수 : 4
# 0.018247756050589675
# 목표 지점까지 걸린 단계 수 : 4
# 0.018462381919662624
# 목표 지점까지 걸린 단계 수 : 18
# 0.0138174822572662
# 목표 지점까지 걸린 단계 수 : 12
# 0.018161673148767182
# 목표 지점까지 걸린 단계 수 : 4
# 0.01977788813757178
# 목표 지점까지 걸린 단계 수 : 10
# 0.015403026549538817
# 목표 지점까지 걸린 단계 수 : 10
# 0.01697699506017636
# 목표 지점까지 걸린 단계 수 : 16
# 0.014870191620056233
# 목표 지점까지 걸린 단계 수 : 6
# 0.012814892599373018
# 목표 지점까지 걸린 단계 수 : 6
# 0.017973812213318313
# 목표 지점까지 걸린 단계 수 : 4
# 0.017719777517190394
# 목표 지점까지 걸린 단계 수 : 4
# 0.01677417448397725
# 목표 지점까지 걸린 단계 수 : 10
# 0.013965434539691818
# 목표 지점까지 걸린 단계 수 : 10
# 0.017589018065889667
# 목표 지점까지 걸린 단계 수 : 4
# 0.018474197218853794
# 목표 지점까지 걸린 단계 수 : 6
# 0.015981582964383234
# 목표 지점까지 걸린 단계 수 : 8
# 0.012452605834837427
# 목표 지점까지 걸린 단계 수 : 6
# 0.017209687437404447
# 목표 지점까지 걸린 단계 수 : 4
# 0.016968634576548125
# 목표 지점까지 걸린 단계 수 : 4
# 0.010079715670409578
# 목표 지점까지 걸린 단계 수 : 10
# 0.010758335065206848
# 목표 지점까지 걸린 단계 수 : 18
# 0.015962080526795985
# 목표 지점까지 걸린 단계 수 : 10
# 0.013515102650802108
# 목표 지점까지 걸린 단계 수 : 12
# 0.017013330265167242
# 목표 지점까지 걸린 단계 수 : 4
# 0.015731821957773062
# 목표 지점까지 걸린 단계 수 : 24
# 0.014300806411189554
# 목표 지점까지 걸린 단계 수 : 8
# 0.022342987371051948
# 목표 지점까지 걸린 단계 수 : 6
# 0.013929290760118895
# 목표 지점까지 걸린 단계 수 : 10
# 0.018095573220614836
# 목표 지점까지 걸린 단계 수 : 6
# 0.016922925281185025
# 목표 지점까지 걸린 단계 수 : 4
# 0.013805661044124118
# 목표 지점까지 걸린 단계 수 : 6
# 0.013501687450666516
# 목표 지점까지 걸린 단계 수 : 12
# 0.018587190208295634
# 목표 지점까지 걸린 단계 수 : 6
# 0.016619080704211142
# 목표 지점까지 걸린 단계 수 : 4
# 0.011762021517910504
# 목표 지점까지 걸린 단계 수 : 8
# 0.0163932497431393
# 목표 지점까지 걸린 단계 수 : 4
# 0.011564165940708554
# 목표 지점까지 걸린 단계 수 : 8
# 0.016174632099716424
# 목표 지점까지 걸린 단계 수 : 4
# 0.015951874275889483
# 목표 지점까지 걸린 단계 수 : 4
# 0.011591116677367952
# 목표 지점까지 걸린 단계 수 : 6
# 0.009922401528928981
# 목표 지점까지 걸린 단계 수 : 8
# 0.009886843940685869
# 목표 지점까지 걸린 단계 수 : 8
# 0.013134619999141256
# 목표 지점까지 걸린 단계 수 : 6
# 0.016327980709083895
# 목표 지점까지 걸린 단계 수 : 10
# 0.011232908674056824
# 목표 지점까지 걸린 단계 수 : 14
# 0.01442911881441536
# 목표 지점까지 걸린 단계 수 : 10
# 0.015955642940088083
# 목표 지점까지 걸린 단계 수 : 4
# 0.015736930754310763
# 목표 지점까지 걸린 단계 수 : 4
# 0.015521883519513724
# 목표 지점까지 걸린 단계 수 : 4
# 0.01135811915255866
# 목표 지점까지 걸린 단계 수 : 6
# 0.011308140022438101
# 목표 지점까지 걸린 단계 수 : 6
# 0.02158520456481111
# 목표 지점까지 걸린 단계 수 : 14
# 0.016761829202643158
# 목표 지점까지 걸린 단계 수 : 8
# 0.01525558776139782
# 목표 지점까지 걸린 단계 수 : 4
# 0.012277037633184607
# 목표 지점까지 걸린 단계 수 : 14
# 0.01658290151559902
# 목표 지점까지 걸린 단계 수 : 20
# 0.01334588666637404
# 목표 지점까지 걸린 단계 수 : 12
# 0.022854821928096847
# 목표 지점까지 걸린 단계 수 : 8
# 0.015442773389334391
# 목표 지점까지 걸린 단계 수 : 4
# 0.015232521876395927
# 목표 지점까지 걸린 단계 수 : 4
# 0.011272124121323529
# 목표 지점까지 걸린 단계 수 : 6
# 0.019465479039187106
# 목표 지점까지 걸린 단계 수 : 10
# 0.020961179536537394
# 목표 지점까지 걸린 단계 수 : 6
# 0.014979224391322377
# 목표 지점까지 걸린 단계 수 : 4
# 0.01107322390435661
# 목표 지점까지 걸린 단계 수 : 8
# 0.014795932276494783
# 목표 지점까지 걸린 단계 수 : 4
# 0.01108706607581847
# 목표 지점까지 걸린 단계 수 : 6
# 0.016842328766943915
# 목표 지점까지 걸린 단계 수 : 6
# 0.020576020029089148
# 목표 지점까지 걸린 단계 수 : 6
# 0.01104354047491729
# 목표 지점까지 걸린 단계 수 : 6
# 0.012374429592309305
# 목표 지점까지 걸린 단계 수 : 6
# 0.013508722151193975
# 목표 지점까지 걸린 단계 수 : 8
# 0.0170830404988446
# 목표 지점까지 걸린 단계 수 : 6
# 0.010921018515105102
# 목표 지점까지 걸린 단계 수 : 6
# 0.02042606180291956
# 목표 지점까지 걸린 단계 수 : 6
# 0.01659730718757285
# 목표 지점까지 걸린 단계 수 : 6
# 0.010883338649302882
# 목표 지점까지 걸린 단계 수 : 6
# 0.012104804489259963
# 목표 지점까지 걸린 단계 수 : 6
# 0.014192789382453469
# 목표 지점까지 걸린 단계 수 : 4
# 0.014005065590520366
# 목표 지점까지 걸린 단계 수 : 4
# 0.014052718276205939
# 목표 지점까지 걸린 단계 수 : 8
# 0.013955569360350556
# 목표 지점까지 걸린 단계 수 : 8
# 0.013886448583398936
# 목표 지점까지 걸린 단계 수 : 4
# 0.013829442748455129
# 목표 지점까지 걸린 단계 수 : 8
# 0.016887974145371853
# 목표 지점까지 걸린 단계 수 : 6
# 0.01042807638297305
# 목표 지점까지 걸린 단계 수 : 6
# 0.013661154007959142
# 목표 지점까지 걸린 단계 수 : 4
# 0.01368865036141051
# 목표 지점까지 걸린 단계 수 : 8
# 0.013180332238391906
# 목표 지점까지 걸린 단계 수 : 10
# 0.013576615587931357
# 목표 지점까지 걸린 단계 수 : 4
# 0.011553883366831191
# 목표 지점까지 걸린 단계 수 : 10
# 0.019968540534765433
# 목표 지점까지 걸린 단계 수 : 8
# 0.016777424841895094
# 목표 지점까지 걸린 단계 수 : 20
# 0.01672394038569036
# 목표 지점까지 걸린 단계 수 : 6
# 0.012846082552327193
# 목표 지점까지 걸린 단계 수 : 14
# 0.019402763592587413
# 목표 지점까지 걸린 단계 수 : 10
# 0.01700416901473148
# 목표 지점까지 걸린 단계 수 : 14
# 0.01736938803492616
# 목표 지점까지 걸린 단계 수 : 14
# 0.013999257479592492
# 목표 지점까지 걸린 단계 수 : 8
# 0.013945845591357753
# 목표 지점까지 걸린 단계 수 : 4
# 0.014117583150274726
# 목표 지점까지 걸린 단계 수 : 14
# 0.013875892215166247
# 목표 지점까지 걸린 단계 수 : 4
# 0.013693921289876426
# 목표 지점까지 걸린 단계 수 : 4
# 0.010356811601849009
# 목표 지점까지 걸린 단계 수 : 6
# 0.013081277544650077
# 목표 지점까지 걸린 단계 수 : 8
# 0.013553883312212966
# 목표 지점까지 걸린 단계 수 : 4
# 0.01745047239228753
# 목표 지점까지 걸린 단계 수 : 20
# 0.013370442454714582
# 목표 지점까지 걸린 단계 수 : 4
# 0.013197292673492844
# 목표 지점까지 걸린 단계 수 : 4
# 0.02336088569820602
# 목표 지점까지 걸린 단계 수 : 12
# 0.013131657805399266
# 목표 지점까지 걸린 단계 수 : 4
# 0.016351818861447848
# 목표 지점까지 걸린 단계 수 : 6
# 0.01292700332268884
# 목표 지점까지 걸린 단계 수 : 4
# 0.01926567569035309
# 목표 지점까지 걸린 단계 수 : 6
# 0.012741289878288542
# 목표 지점까지 걸린 단계 수 : 4
# 0.01257774802100195
# 목표 지점까지 걸린 단계 수 : 4
# 0.014831445806064464
# 목표 지점까지 걸린 단계 수 : 24
# 0.010990697603038752
# 목표 지점까지 걸린 단계 수 : 6
# 0.012394754447932144
# 목표 지점까지 걸린 단계 수 : 4
# 0.01591493398238117
# 목표 지점까지 걸린 단계 수 : 10
# 0.015883063055139757
# 목표 지점까지 걸린 단계 수 : 6
# 0.016349045892870284
# 목표 지점까지 걸린 단계 수 : 18
# 0.010941440013193804
# 목표 지점까지 걸린 단계 수 : 6
# 0.009756364727788708
# 목표 지점까지 걸린 단계 수 : 6
# 0.014842542059279373
# 목표 지점까지 걸린 단계 수 : 6
# 0.011377319984908735
# 목표 지점까지 걸린 단계 수 : 10
# 0.010809676615636171
# 목표 지점까지 걸린 단계 수 : 6
# 0.012376099334301838
# 목표 지점까지 걸린 단계 수 : 4
# 0.01894151137407421
# 목표 지점까지 걸린 단계 수 : 6
# 0.0122029902921591
# 목표 지점까지 걸린 단계 수 : 4
# 0.016186462113895933
# 목표 지점까지 걸린 단계 수 : 10
# 0.01897164633491824
# 목표 지점까지 걸린 단계 수 : 10
# 0.01563826083561784
# 목표 지점까지 걸린 단계 수 : 10
# 0.015897246131972298
# 목표 지점까지 걸린 단계 수 : 6
# 0.012211045442718671
# 목표 지점까지 걸린 단계 수 : 4
# 0.01205656343814368
# 목표 지점까지 걸린 단계 수 : 4
# 0.00960965471127534
# 목표 지점까지 걸린 단계 수 : 6
# 0.011899512135797569
# 목표 지점까지 걸린 단계 수 : 4
# 0.011969708877047236
# 목표 지점까지 걸린 단계 수 : 8
# 0.011806177522883932
# 목표 지점까지 걸린 단계 수 : 4
# 0.011658408431636402
# 목표 지점까지 걸린 단계 수 : 4
# 0.015508503485591296
# 목표 지점까지 걸린 단계 수 : 12
# 0.011622812059205345
# 목표 지점까지 걸린 단계 수 : 4
# 0.019816376293091326
# 목표 지점까지 걸린 단계 수 : 8
# 0.011514010798746116
# 목표 지점까지 걸린 단계 수 : 4
# 0.014102664064025994
# 목표 지점까지 걸린 단계 수 : 6
# 0.011350481710540039
# 목표 지점까지 걸린 단계 수 : 4
# 0.01392510986364312
# 목표 지점까지 걸린 단계 수 : 6
# 0.013858627101665355
# 목표 지점까지 걸린 단계 수 : 6
# 0.010781224901609598
# 목표 지점까지 걸린 단계 수 : 12
# 0.011303807375047187
# 목표 지점까지 걸린 단계 수 : 4
# 0.009421981385346334
# 목표 지점까지 걸린 단계 수 : 6
# 0.011164516000297942
# 목표 지점까지 걸린 단계 수 : 4
# 0.016991346385321654
# 목표 지점까지 걸린 단계 수 : 10
# 0.015945801355094408
# 목표 지점까지 걸린 단계 수 : 16
# 0.00951384581704473
# 목표 지점까지 걸린 단계 수 : 6
# 0.011241136589490913
# 목표 지점까지 걸린 단계 수 : 4
# 0.013175556527151647
# 목표 지점까지 걸린 단계 수 : 8
# 0.011147213085160812
# 목표 지점까지 걸린 단계 수 : 4
# 0.011008763634078836
# 목표 지점까지 걸린 단계 수 : 4
# 0.01087255880861962
# 목표 지점까지 걸린 단계 수 : 4
# 0.010012296656697672
# 목표 지점까지 걸린 단계 수 : 8
# 0.014414287353695002
# 목표 지점까지 걸린 단계 수 : 6
# 0.014329613385453036
# 목표 지점까지 걸린 단계 수 : 6
# 0.010752807054128136
# 목표 지점까지 걸린 단계 수 : 4
# 0.01754066963327676
# 목표 지점까지 걸린 단계 수 : 8
# 0.013522055594159033
# 목표 지점까지 걸린 단계 수 : 6
# 0.010664183471238153
# 목표 지점까지 걸린 단계 수 : 4
# 0.014073732143439072
# 목표 지점까지 걸린 단계 수 : 6
# 0.010038422829963145
# 목표 지점까지 걸린 단계 수 : 6
# 0.01050513915840609
# 목표 지점까지 걸린 단계 수 : 4
# 0.011625648598487248
# 목표 지점까지 걸린 단계 수 : 10
# 0.010466158665880798
# 목표 지점까지 걸린 단계 수 : 4
# 0.009872782480725956
# 목표 지점까지 걸린 단계 수 : 6
# 0.01032339674989953
# 목표 지점까지 걸린 단계 수 : 4
# 0.010197707901007963
# 목표 지점까지 걸린 단계 수 : 4
# 0.012480811441660383
# 목표 지점까지 걸린 단계 수 : 8
# 0.010127734083415649
# 목표 지점까지 걸린 단계 수 : 4
# 0.010004977556639191
# 목표 지점까지 걸린 단계 수 : 4
# 0.012943199314571288
# 목표 지점까지 걸린 단계 수 : 6
# 0.009883030066621251
# 목표 지점까지 걸린 단계 수 : 4
# 0.009764115482291835
# 목표 지점까지 걸린 단계 수 : 4
# 0.009647109781034058
# 목표 지점까지 걸린 단계 수 : 4
# 0.009531977281654835
# 목표 지점까지 걸린 단계 수 : 4
# 0.009013479674913921
# 목표 지점까지 걸린 단계 수 : 6
# 0.009428301034351605
# 목표 지점까지 걸린 단계 수 : 4
# 0.012156971428963187
# 목표 지점까지 걸린 단계 수 : 8
# 0.016053323360846042
# 목표 지점까지 걸린 단계 수 : 10
# 0.009487752879331138
# 목표 지점까지 걸린 단계 수 : 4
# 0.00897079964963425
# 목표 지점까지 걸린 단계 수 : 8
# 0.009224875319541179
# 목표 지점까지 걸린 단계 수 : 6
# 0.008875512113380016
# 목표 지점까지 걸린 단계 수 : 6
# 0.009445326998807499
# 목표 지점까지 걸린 단계 수 : 4
# 0.016486483285638412
# 목표 지점까지 걸린 단계 수 : 8
# 0.009110408563407044
# 목표 지점까지 걸린 단계 수 : 6
# 0.009321770403055013
# 목표 지점까지 걸린 단계 수 : 4
# 0.009212473963253379
# 목표 지점까지 걸린 단계 수 : 4
# 0.009104880323291431
# 목표 지점까지 걸린 단계 수 : 4
# 0.008998958897902101
# 목표 지점까지 걸린 단계 수 : 4
# 0.008775572483260094
# 목표 지점까지 걸린 단계 수 : 8
# 0.010843154402380997
# 목표 지점까지 걸린 단계 수 : 10
# 0.008727561667011122
# 목표 지점까지 걸린 단계 수 : 6
# 0.016513171108987215
# 목표 지점까지 걸린 단계 수 : 6
# 0.009055355595543157
# 목표 지점까지 걸린 단계 수 : 4
# 0.008950143050168058
# 목표 지점까지 걸린 단계 수 : 4
# 0.008846561343449535
# 목표 지점까지 걸린 단계 수 : 4
# 0.00874458114868358
# 목표 지점까지 걸린 단계 수 : 4
# 0.00871220919592984
# 목표 지점까지 걸린 단계 수 : 12
# 0.010769534174848203
# 목표 지점까지 걸린 단계 수 : 10
# 0.012791794496499004
# 목표 지점까지 걸린 단계 수 : 6
# 0.008767602162423005
# 목표 지점까지 걸린 단계 수 : 4
# 0.008666610270676625
# 목표 지점까지 걸린 단계 수 : 4
# 0.00856718044516
# 목표 지점까지 걸린 단계 수 : 4
# 0.0153178851228528
# 목표 지점까지 걸린 단계 수 : 10
# 0.008552735566626349
# 목표 지점까지 걸린 단계 수 : 4
# 0.008454855882969362
# 목표 지점까지 걸린 단계 수 : 4
# 0.008602023658251162
# 목표 지점까지 걸린 단계 수 : 6
# 0.008704103089331797
# 목표 지점까지 걸린 단계 수 : 8
# 0.008446657202015706
# 목표 지점까지 걸린 단계 수 : 4
# 0.012675572661684884
# 목표 지점까지 걸린 단계 수 : 10
# 0.008429082261546261
# 목표 지점까지 걸린 단계 수 : 4
# 0.010668216163551292
# 목표 지점까지 걸린 단계 수 : 12
# 0.0123620552123503
# 목표 지점까지 걸린 단계 수 : 6
# 0.008457068138284937
# 목표 지점까지 걸린 단계 수 : 4
# 0.012237962092662522
# 목표 지점까지 걸린 단계 수 : 6
# 0.013359110536745308
# 목표 지점까지 걸린 단계 수 : 10
# 0.00847000670543352
# 목표 지점까지 걸린 단계 수 : 4
# 0.008372803814173213
# 목표 지점까지 걸린 단계 수 : 4
# 0.008277113917732254
# 목표 지점까지 걸린 단계 수 : 4
# 0.008182908989973772
# 목표 지점까지 걸린 단계 수 : 4
# 0.00809016155966448
# 목표 지점까지 걸린 단계 수 : 4
# 0.01157920792313831
# 목표 지점까지 걸린 단계 수 : 6
# 0.01567607962712103
# 목표 지점까지 걸린 단계 수 : 8
# 0.007994524332729819
# 목표 지점까지 걸린 단계 수 : 4
# 0.011759519767160664
# 목표 지점까지 걸린 단계 수 : 8
# 0.0119663306965746
# 목표 지점까지 걸린 단계 수 : 6
# 0.007993791170168837
# 목표 지점까지 걸린 단계 수 : 4
# 0.00790395578624016
# 목표 지점까지 걸린 단계 수 : 4
# 0.007815497574581956
# 목표 지점까지 걸린 단계 수 : 4
# 0.013211201220130642
# 목표 지점까지 걸린 단계 수 : 20
# 0.007726862878047691
# 목표 지점까지 걸린 단계 수 : 4
# 0.007641142411515117
# 목표 지점까지 걸린 단계 수 : 4
# 0.011621075603045622
# 목표 지점까지 걸린 단계 수 : 8
# 0.014714486211092129
# 목표 지점까지 걸린 단계 수 : 8
# 0.011229851000387009
# 목표 지점까지 걸린 단계 수 : 6
# 0.00849786691499109
# 목표 지점까지 걸린 단계 수 : 6
# 0.015537761514321485
# 목표 지점까지 걸린 단계 수 : 6
# 0.0077071684121519796
# 목표 지점까지 걸린 단계 수 : 4
# 0.007621923889287632
# 목표 지점까지 걸린 단계 수 : 4
# 0.01643937380788972
# 목표 지점까지 걸린 단계 수 : 8
# 0.007585748052294575
# 목표 지점까지 걸린 단계 수 : 4
# 0.0075023294750653086
# 목표 지점까지 걸린 단계 수 : 4
# 0.010242804623331214
# 목표 지점까지 걸린 단계 수 : 12
# 0.011071406569759537
# 목표 지점까지 걸린 단계 수 : 6
# 0.007538466114924355
# 목표 지점까지 걸린 단계 수 : 4
# 0.007455649234023587
# 목표 지점까지 걸린 단계 수 : 4
# 0.007374080784933804
# 목표 지점까지 걸린 단계 수 : 4
# 0.010849275864012436
# 목표 지점까지 걸린 단계 수 : 6
# 0.008659141882867927
# 목표 지점까지 걸린 단계 수 : 8
# 0.0073590377076028085
# 목표 지점까지 걸린 단계 수 : 4
# 0.0072788376943737215
# 목표 지점까지 걸린 단계 수 : 4
# 0.007199840098179547
# 목표 지점까지 걸린 단계 수 : 4
# 0.0071220229912483946
# 목표 지점까지 걸린 단계 수 : 4
# 0.010905292332660965
# 목표 지점까지 걸린 단계 수 : 10
# 0.015114537675773504
# 목표 지점까지 걸린 단계 수 : 8
# 0.01505838787567955
# 목표 지점까지 걸린 단계 수 : 6
# 0.010952721132001228
# 목표 지점까지 걸린 단계 수 : 8
# 0.010952894299487578
# 목표 지점까지 걸린 단계 수 : 8
# 0.008424114314534936
# 목표 지점까지 걸린 단계 수 : 6
# 0.008245369675334319
# 목표 지점까지 걸린 단계 수 : 6
# 0.007286211629185857
# 목표 지점까지 걸린 단계 수 : 4
# 0.021773319755196946
# 목표 지점까지 걸린 단계 수 : 12
# 0.007239158126154735
# 목표 지점까지 걸린 단계 수 : 4
# 0.010527246587942046
# 목표 지점까지 걸린 단계 수 : 12
# 0.007193126827262905
# 목표 지점까지 걸린 단계 수 : 4
# 0.007115487874014739
# 목표 지점까지 걸린 단계 수 : 4
# 0.011033975698756679
# 목표 지점까지 걸린 단계 수 : 6
# 0.013113630847739907
# 목표 지점까지 걸린 단계 수 : 14
# 0.011149405083429584
# 목표 지점까지 걸린 단계 수 : 6
# 0.007194641350253023
# 목표 지점까지 걸린 단계 수 : 4
# 0.013521285166478672
# 목표 지점까지 걸린 단계 수 : 14
# 0.007233175961292332
# 목표 지점까지 걸린 단계 수 : 4
# 0.00839982930564706
# 목표 지점까지 걸린 단계 수 : 6
# 0.01215279482269016
# 목표 지점까지 걸린 단계 수 : 12
# 0.007174828784376863
# 목표 지점까지 걸린 단계 수 : 4
# 0.014157914629084528
# 목표 지점까지 걸린 단계 수 : 10
# 0.007140921294523553
# 목표 지점까지 걸린 단계 수 : 4
# 0.007063879054784616
# 목표 지점까지 걸린 단계 수 : 4
# 0.006987985498012703
# 목표 지점까지 걸린 단계 수 : 4
# 0.006913219654592448
# 목표 지점까지 걸린 단계 수 : 4
# 0.008050769526906948
# 목표 지점까지 걸린 단계 수 : 6
# 0.019363999533172707
# 목표 지점까지 걸린 단계 수 : 12
# 0.006872950506377762
# 목표 지점까지 걸린 단계 수 : 4
# 0.006800024190828979
# 목표 지점까지 걸린 단계 수 : 4
# 0.0067281684157477345
# 목표 지점까지 걸린 단계 수 : 4
# 0.006657363912050379
# 목표 지점까지 걸린 단계 수 : 4
# 0.006587591802767731
# 목표 지점까지 걸린 단계 수 : 4
# 0.010566860320791516
# 목표 지점까지 걸린 단계 수 : 6
# 0.008370210679875534
# 목표 지점까지 걸린 단계 수 : 8
# 0.0065916847334355905
# 목표 지점까지 걸린 단계 수 : 4
# 0.007919479173767868
# 목표 지점까지 걸린 단계 수 : 6
# 0.011020452108651962
# 목표 지점까지 걸린 단계 수 : 8
# 0.008009085099630595
# 목표 지점까지 걸린 단계 수 : 6
# 0.008016111888597355
# 목표 지점까지 걸린 단계 수 : 6
# 0.006658357102150084
# 목표 지점까지 걸린 단계 수 : 4
# 0.00658853608746332
# 목표 지점까지 걸린 단계 수 : 4
# 0.006519726855198027
# 목표 지점까지 걸린 단계 수 : 4
# 0.01605087954732494
# 목표 지점까지 걸린 단계 수 : 14
# 0.008248623469760671
# 목표 지점까지 걸린 단계 수 : 8
# 0.0147627287603712
# 목표 지점까지 걸린 단계 수 : 6
# 0.010713807023090618
# 목표 지점까지 걸린 단계 수 : 6
# 0.01023064265980067
# 목표 지점까지 걸린 단계 수 : 6
# 0.006589662819059844
# 목표 지점까지 걸린 단계 수 : 4
# 0.010174892930523219
# 목표 지점까지 걸린 단계 수 : 6
# 0.006531866114783222
# 목표 지점까지 걸린 단계 수 : 4
# 0.007972676607745088
# 목표 지점까지 걸린 단계 수 : 6
# 0.007981351148873939
# 목표 지점까지 걸린 단계 수 : 6
# 0.006520397626805632
# 목표 지점까지 걸린 단계 수 : 4
# 0.006452618420351497
# 목표 지점까지 걸린 단계 수 : 4
# 0.01023957850225031
# 목표 지점까지 걸린 단계 수 : 8
# 0.007957824411135586
# 목표 지점까지 걸린 단계 수 : 6
# 0.0064815708649123005
# 목표 지점까지 걸린 단계 수 : 4
# 0.0064143286830560114
# 목표 지점까지 걸린 단계 수 : 4
# 0.009942265482866641
# 목표 지점까지 걸린 단계 수 : 6
# 0.010529535926765851
# 목표 지점까지 걸린 단계 수 : 6
# 0.0063745703731380166
# 목표 지점까지 걸린 단계 수 : 4
# 0.006308776596137225
# 목표 지점까지 걸린 단계 수 : 4
# 0.0062439245494268075
# 목표 지점까지 걸린 단계 수 : 4
# 0.006179997690752864
# 목표 지점까지 걸린 단계 수 : 4
# 0.012849245842044082
# 목표 지점까지 걸린 단계 수 : 14
# 0.0061487026545758855
# 목표 지점까지 걸린 단계 수 : 4
# 0.014359093784020047
# 목표 지점까지 걸린 단계 수 : 6
# 0.010678860768378179
# 목표 지점까지 걸린 단계 수 : 8
# 0.0061529156184823575
# 목표 지점까지 걸린 단계 수 : 4
# 0.006090427793061487
# 목표 지점까지 걸린 단계 수 : 4
# 0.0060288206053019655
# 목표 지점까지 걸린 단계 수 : 4
# 0.010148211838732449
# 목표 지점까지 걸린 단계 수 : 6
# 0.009616804453022654
# 목표 지점까지 걸린 단계 수 : 6
# 0.005996394955889314
# 목표 지점까지 걸린 단계 수 : 4
# 0.014185036912674157
# 목표 지점까지 걸린 단계 수 : 6
# 0.005940307251115565
# 목표 지점까지 걸린 단계 수 : 4
# 0.007369776711773232
# 목표 지점까지 걸린 단계 수 : 6
# 0.00589357368009287
# 목표 지점까지 걸린 단계 수 : 4
# 0.009457087475790299
# 목표 지점까지 걸린 단계 수 : 6
# 0.005851259157433952
# 목표 지점까지 걸린 단계 수 : 4
# 0.007873222545212041
# 목표 지점까지 걸린 단계 수 : 8
# 0.011266696545246452
# 목표 지점까지 걸린 단계 수 : 14
# 0.0058443968143554875
# 목표 지점까지 걸린 단계 수 : 4
# 0.005786270932539986
# 목표 지점까지 걸린 단계 수 : 4
# 0.0057289508789999805
# 목표 지점까지 걸린 단계 수 : 4
# 0.010230509397491303
# 목표 지점까지 걸린 단계 수 : 10
# 0.0057533748150898345
# 목표 지점까지 걸린 단계 수 : 4
# 0.005696485190528192
# 목표 지점까지 걸린 단계 수 : 4
# 0.005640380145300702
# 목표 지점까지 걸린 단계 수 : 4
# 0.009739493013924447
# 목표 지점까지 걸린 단계 수 : 6
# 0.009754615453182222
# 목표 지점까지 걸린 단계 수 : 6
# 0.011929227478673268
# 목표 지점까지 걸린 단계 수 : 10
# 0.005690695685572317
# 목표 지점까지 걸린 단계 수 : 4
# 0.01000950130375007
# 목표 지점까지 걸린 단계 수 : 8
# 0.005686709784993846
# 목표 지점까지 걸린 단계 수 : 4
# 0.005630593797471745
# 목표 지점까지 걸린 단계 수 : 4
# 0.0072654966138708255
# 목표 지점까지 걸린 단계 수 : 6
# 0.013145500667649912
# 목표 지점까지 걸린 단계 수 : 8
# 0.0056434323893078675
# 목표 지점까지 걸린 단계 수 : 4
# 0.007260882150361983
# 목표 지점까지 걸린 단계 수 : 6
# 0.010193981796108337
# 목표 지점까지 걸린 단계 수 : 10
# 0.009918671612416774
# 목표 지점까지 걸린 단계 수 : 6
# 0.005705595690045223
# 목표 지점까지 걸린 단계 수 : 4
# 0.009871937356768612
# 목표 지점까지 걸린 단계 수 : 6
# 0.009882470938014795
# 목표 지점까지 걸린 단계 수 : 6
# 0.005691338639058394
# 목표 지점까지 걸린 단계 수 : 4
# 0.0056349570410419575
# 목표 지점까지 걸린 단계 수 : 4
# 0.013750682825265759
# 목표 지점까지 걸린 단계 수 : 6
# 0.014825074839895744
# 목표 지점까지 걸린 단계 수 : 8
# 0.00563061235178329
# 목표 지점까지 걸린 단계 수 : 4
# 0.005575160914495267
# 목표 지점까지 걸린 단계 수 : 4
# 0.005520474898003239
# 목표 지점까지 걸린 단계 수 : 4
# 0.012703669335212678
# 목표 지점까지 걸린 단계 수 : 10
# 0.005545776106402334
# 목표 지점까지 걸린 단계 수 : 4
# 0.009641430676614798
# 목표 지점까지 걸린 단계 수 : 6
# 0.009303398375808888
# 목표 지점까지 걸린 단계 수 : 6
# 0.01247330341179688
# 목표 지점까지 걸린 단계 수 : 10
# 0.013687295330466961
# 목표 지점까지 걸린 단계 수 : 6
# 0.014682849687006255
# 목표 지점까지 걸린 단계 수 : 22
# 0.005623625623092418
# 목표 지점까지 걸린 단계 수 : 4
# 0.007418940859452827
# 목표 지점까지 걸린 단계 수 : 6
# 0.02147920595615474
# 목표 지점까지 걸린 단계 수 : 10
# 0.013811479007556665
# 목표 지점까지 걸린 단계 수 : 6
# 0.009320041240655053
# 목표 지점까지 걸린 단계 수 : 6
# 0.018832425683448645
# 목표 지점까지 걸린 단계 수 : 8
# 0.01380580746826765
# 목표 지점까지 걸린 단계 수 : 6
# 0.005655200951721465
# 목표 지점까지 걸린 단계 수 : 4
# 0.005599717847470723
# 목표 지점까지 걸린 단계 수 : 4
# 0.005544998407528506
# 목표 지점까지 걸린 단계 수 : 4
# 0.005491029502008499
# 목표 지점까지 걸린 단계 수 : 4
# 0.005437798263570159
# 목표 지점까지 걸린 단계 수 : 4
# 0.007436465324427391
# 목표 지점까지 걸린 단계 수 : 6
# 0.007336871470915288
# 목표 지점까지 걸린 단계 수 : 6
# 0.00542217125897719
# 목표 지점까지 걸린 단계 수 : 4
# 0.005369930274487608
# 목표 지점까지 걸린 단계 수 : 4
# 0.0053183957742126
# 목표 지점까지 걸린 단계 수 : 4
# 0.005267555821570458
# 목표 지점까지 걸린 단계 수 : 4
# 0.0052173987145639755
# 목표 지점까지 걸린 단계 수 : 4
# 0.00516791298072114
# 목표 지점까지 걸린 단계 수 : 4
# 0.005119087372155967
# 목표 지점까지 걸린 단계 수 : 4
# 0.005070910860731831
# 목표 지점까지 걸린 단계 수 : 4
# 0.0050233726333380885
# 목표 지점까지 걸린 단계 수 : 4
# 0.004976462087262004
# 목표 지점까지 걸린 단계 수 : 4
# 0.00884279542035421
# 목표 지점까지 걸린 단계 수 : 12
# 0.013232853883865373
# 목표 지점까지 걸린 단계 수 : 6
# 0.008587278626248973
# 목표 지점까지 걸린 단계 수 : 6
# 0.004992118861633588
# 목표 지점까지 걸린 단계 수 : 4
# 0.009364809444788319
# 목표 지점까지 걸린 단계 수 : 8
# 0.009041635790933936
# 목표 지점까지 걸린 단계 수 : 6
# 0.009068912797838294
# 목표 지점까지 걸린 단계 수 : 6
# 0.00909508843183561
# 목표 지점까지 걸린 단계 수 : 6
# 0.005073045534933027
# 목표 지점까지 걸린 단계 수 : 4
# 0.007198965777942795
# 목표 지점까지 걸린 단계 수 : 6
# 0.005036777286198987
# 목표 지점까지 걸린 단계 수 : 4
# 0.004989502206512217
# 목표 지점까지 걸린 단계 수 : 4
# 0.008030230498940583
# 목표 지점까지 걸린 단계 수 : 8
# 0.0049969238347761374
# 목표 지점까지 걸린 단계 수 : 4
# 0.009029401898661846
# 목표 지점까지 걸린 단계 수 : 6
# 0.004980038580586071
# 목표 지점까지 걸린 단계 수 : 4
# 0.004933338674600898
# 목표 지점까지 걸린 단계 수 : 4
# 0.012572964569435977
# 목표 지점까지 걸린 단계 수 : 14
# 0.007083057709826424
# 목표 지점까지 걸린 단계 수 : 6
# 0.00909289019971507
# 목표 지점까지 걸린 단계 수 : 6
# 0.005039511274124206
# 목표 지점까지 걸린 단계 수 : 4
# 0.009412333128607092
# 목표 지점까지 걸린 단계 수 : 8
# 0.013109262301616006
# 목표 지점까지 걸린 단계 수 : 6
# 0.005041139466682276
# 목표 지점까지 걸린 단계 수 : 4
# 0.004993624196872881
# 목표 지점까지 걸린 단계 수 : 4
# 0.007058404368420604
# 목표 지점까지 걸린 단계 수 : 6
# 0.004969739235332768
# 목표 지점까지 걸린 단계 수 : 4
# 0.012732895527772375
# 목표 지점까지 걸린 단계 수 : 18
# 0.004941784744015215
# 목표 지점까지 걸린 단계 수 : 4
# 0.007032350317514563
# 목표 지점까지 걸린 단계 수 : 6
# 0.004919982210062623
# 목표 지점까지 걸린 단계 수 : 4
# 0.004874169432909373
# 목표 지점까지 걸린 단계 수 : 4
# 0.0048289603613848875
# 목표 지점까지 걸린 단계 수 : 4
# 0.007906251081395865
# 목표 지점까지 걸린 단계 수 : 8
# 0.008509028860507403
# 목표 지점까지 걸린 단계 수 : 6
# 0.004846789850289079
# 목표 지점까지 걸린 단계 수 : 4
# 0.004801927928803462
# 목표 지점까지 걸린 단계 수 : 4
# 0.004757654179394014
# 목표 지점까지 걸린 단계 수 : 4
# 0.00840046969985249
# 목표 지점까지 걸린 단계 수 : 6
# 0.004724472528139026
# 목표 지점까지 걸린 단계 수 : 4
# 0.004681245785914737
# 목표 지점까지 걸린 단계 수 : 4
# 0.006861880780702254
# 목표 지점까지 걸린 단계 수 : 6
# 0.012035534461894593
# 목표 지점까지 걸린 단계 수 : 10
# 0.004736242614142808
# 목표 지점까지 걸린 단계 수 : 4
# 0.008369889401807468
# 목표 지점까지 걸린 단계 수 : 6
# 0.004704313290077755
# 목표 지점까지 걸린 단계 수 : 4
# 0.0046613875314423375
# 목표 지점까지 걸린 단계 수 : 4
# 0.004619016725499123
# 목표 지점까지 걸린 단계 수 : 4
# 0.008656787487466289
# 목표 지점까지 걸린 단계 수 : 6
# 0.004604527536265168
# 목표 지점까지 걸린 단계 수 : 4
# 0.008646216544464042
# 목표 지점까지 걸린 단계 수 : 6
# 0.004592026632816312
# 목표 지점까지 걸린 단계 수 : 4
# 0.004550352137461078
# 목표 지점까지 걸린 단계 수 : 4
# 0.012565583836845251
# 목표 지점까지 걸린 단계 수 : 18
# 0.00894646998944107
# 목표 지점까지 걸린 단계 수 : 8
# 0.010018284883857628
# 목표 지점까지 걸린 단계 수 : 10
# 0.004631905527868532
# 목표 지점까지 걸린 단계 수 : 4
# 0.004589647280515613
# 목표 지점까지 걸린 단계 수 : 4
# 0.004547938021386033
# 목표 지점까지 걸린 단계 수 : 4
# 0.012657217663099421
# 목표 지점까지 걸린 단계 수 : 6
# 0.004518158563953115
# 목표 지점까지 걸린 단계 수 : 4
# 0.007825200363711773
# 목표 지점까지 걸린 단계 수 : 8
# 0.004537359217923795
# 목표 지점까지 걸린 단계 수 : 4
# 0.0044963370470615105
# 목표 지점까지 걸린 단계 수 : 4
# 0.00445584345061889
# 목표 지점까지 걸린 단계 수 : 4
# 0.0067277956534934485
# 목표 지점까지 걸린 단계 수 : 6
# 0.004438420380344518
# 목표 지점까지 걸린 단계 수 : 4
# 0.00439870147410637
# 목표 지점까지 걸린 단계 수 : 4
# 0.0043594891268669556
# 목표 지점까지 걸린 단계 수 : 4
# 0.004320775129279517
# 목표 지점까지 걸린 단계 수 : 4
# 0.0042825514300368905
# 목표 지점까지 걸린 단계 수 : 4
# 0.0042448101324399495
# 목표 지점까지 걸린 단계 수 : 4
# 0.007921191254254625
# 목표 지점까지 걸린 단계 수 : 6
# 0.007964857107033402
# 목표 지점까지 걸린 단계 수 : 6
# 0.004237092242469931
# 목표 지점까지 걸린 단계 수 : 4
# 0.0041999578617355135
# 목표 지점까지 걸린 단계 수 : 4
# 0.007925583181634561
# 목표 지점까지 걸린 단계 수 : 6
# 0.004180965915491212
# 목표 지점까지 걸린 단계 수 : 4
# 0.004144533492753816
# 목표 지점까지 걸린 단계 수 : 4
# 0.007888792403272782
# 목표 지점까지 걸린 단계 수 : 6
# 0.004128146942215333
# 목표 지점까지 걸린 단계 수 : 4
# 0.008721137391526579
# 목표 지점까지 걸린 단계 수 : 8
# 0.00414607720566109
# 목표 지점까지 걸린 단계 수 : 4
# 0.004110001375372492
# 목표 지점까지 걸린 단계 수 : 4
# 0.004074374414440071
# 목표 지점까지 걸린 단계 수 : 4
# 0.007861964690599202
# 목표 지점까지 걸린 단계 수 : 6
# 0.00798822401011124
# 목표 지점까지 걸린 단계 수 : 6
# 0.00795247311316196
# 목표 지점까지 걸린 단계 수 : 6
# 0.004111457611240522
# 목표 지점까지 걸린 단계 수 : 4
# 0.004075687379168552
# 목표 지점까지 걸린 단계 수 : 4
# 0.004040363105969967
# 목표 지점까지 걸린 단계 수 : 4
# 0.008669572760380835
# 목표 지점까지 걸린 단계 수 : 8
# 0.004061746170540045
# 목표 지점까지 걸린 단계 수 : 4
# 0.007925970022218495
# 목표 지점까지 걸린 단계 수 : 6
# 0.012091444269294857
# 목표 지점까지 걸린 단계 수 : 6
# 0.0040615616771926474
# 목표 지점까지 걸린 단계 수 : 4
# 0.009127767247628961
# 목표 지점까지 걸린 단계 수 : 10
# 0.007983039489145062
# 목표 지점까지 걸린 단계 수 : 6
# 0.004111160217946483
# 목표 지점까지 걸린 단계 수 : 4
# 0.008752115430713053
# 목표 지점까지 걸린 단계 수 : 8
# 0.004125360344381303
# 목표 지점까지 걸린 단계 수 : 4
# 0.004089320062029771
# 목표 지점까지 걸린 단계 수 : 4
# 0.007962443691391437
# 목표 지점까지 걸린 단계 수 : 6
# 0.00407981172193652
# 목표 지점까지 걸린 단계 수 : 4
# 0.004044293337045916
# 목표 지점까지 걸린 단계 수 : 4
# 0.00400921905698861
# 목표 지점까지 걸린 단계 수 : 4
# 0.003974581771339684
# 목표 지점까지 걸린 단계 수 : 4
# 0.008198997487095752
# 목표 지점까지 걸린 단계 수 : 10
# 0.004006382698926593
# 목표 지점까지 걸린 단계 수 : 4
# 0.003971743086093105
# 목표 지점까지 걸린 단계 수 : 4
# 0.003937534049049875
# 목표 지점까지 걸린 단계 수 : 4
# 0.0039037487281276123
# 목표 지점까지 걸린 단계 수 : 4
# 0.0038703803947233023
# 목표 지점까지 걸린 단계 수 : 4
# 0.007704066670352651
# 목표 지점까지 걸린 단계 수 : 6
# 0.0074562722725454444
# 목표 지점까지 걸린 단계 수 : 8
# 0.008594671980569082
# 목표 지점까지 걸린 단계 수 : 8
# 0.0039690888241150635
# 목표 지점까지 걸린 단계 수 : 4
# 0.007892201048106298
# 목표 지점까지 걸린 단계 수 : 6
# 0.00396121087642165
# 목표 지점까지 걸린 단계 수 : 4
# 0.008622687110049092
# 목표 지점까지 걸린 단계 수 : 8
# 0.008500514101850203
# 목표 지점까지 걸린 단계 수 : 8
# 0.004023816710282638
# 목표 지점까지 걸린 단계 수 : 4
# 0.0039887404170531465
# 목표 지점까지 걸린 단계 수 : 4
# 0.007840681330435674
# 목표 지점까지 걸린 단계 수 : 12
# 0.003973999017890813
# 목표 지점까지 걸린 단계 수 : 4
# 0.003939614315499815
# 목표 지점까지 걸린 단계 수 : 4
# 0.0039056581549907696
# 목표 지점까지 걸린 단계 수 : 4
# 0.006231935711284366
# 목표 지점까지 걸린 단계 수 : 6
# 0.007789352382183798
# 목표 지점까지 걸린 단계 수 : 6
# 0.0074883978338323234
# 목표 지점까지 걸린 단계 수 : 8
# 0.003965810553049641
# 목표 지점까지 걸린 단계 수 : 4
# 0.003931497202546763
# 목표 지점까지 걸린 단계 수 : 4
# 0.007833476859361692
# 목표 지점까지 걸린 단계 수 : 6
# 0.006277259184591356
# 목표 지점까지 걸린 단계 수 : 6
# 0.0075660139590174175
# 목표 지점까지 걸린 단계 수 : 8
# 0.004000757111017099
# 목표 지점까지 걸린 단계 수 : 4
# 0.003965951854623041
# 목표 지점까지 걸린 단계 수 : 4
# 0.003931582804226362
# 목표 지점까지 걸린 단계 수 : 4
# 0.006194359578797909
# 목표 지점까지 걸린 단계 수 : 6
# 0.003909775092498659
# 목표 지점까지 걸린 단계 수 : 4
# 0.007515180410824093
# 목표 지점까지 걸린 단계 수 : 8
# 0.013159014856859393
# 목표 지점까지 걸린 단계 수 : 8
# 0.003934627761326533
# 목표 지점까지 걸린 단계 수 : 4
# 0.008563609361563147
# 목표 지점까지 걸린 단계 수 : 8
# 0.003957353439868763
# 목표 지점까지 걸린 단계 수 : 4
# 0.0039230913895199615
# 목표 지점까지 걸린 단계 수 : 4
# 0.003889256828772454
# 목표 지점까지 걸린 단계 수 : 4
# 0.0038558429131403046
# 목표 지점까지 걸린 단계 수 : 4
# 0.003822842929585693
# 목표 지점까지 걸린 단계 수 : 4
# 0.006117410969263021
# 목표 지점까지 걸린 단계 수 : 6
# 0.013011560951760474
# 목표 지점까지 걸린 단계 수 : 8
# 0.008087185766330517
# 목표 지점까지 걸린 단계 수 : 10
# 0.0038761138582214735
# 목표 지점까지 걸린 단계 수 : 4
# 0.007831016985217307
# 목표 지점까지 걸린 단계 수 : 6
# 0.006264486231858574
# 목표 지점까지 걸린 단계 수 : 6
# 0.0038939023654283797
# 목표 지점까지 걸린 단계 수 : 4
# 0.003860459105485277
# 목표 지점까지 걸린 단계 수 : 4
# 0.0038274297195949117
# 목표 지점까지 걸린 단계 수 : 4
# 0.0037948076353869903
# 목표 지점까지 걸린 단계 수 : 4
# 0.003762586405712545
# 목표 지점까지 걸린 단계 수 : 4
# 0.007732110452551441
# 목표 지점까지 걸린 단계 수 : 6
# 0.0061924856736571
# 목표 지점까지 걸린 단계 수 : 6
# 0.01283362261275272
# 목표 지점까지 걸린 단계 수 : 14
# 0.0038079236144129974
# 목표 지점까지 걸린 단계 수 : 4
# 0.0037754823724645767
# 목표 지점까지 걸린 단계 수 : 4
# 0.0060628057841197805
# 목표 지점까지 걸린 단계 수 : 6
# 0.0037566601255860227
# 목표 지점까지 걸린 단계 수 : 4
# 0.00618029485261188
# 목표 지점까지 걸린 단계 수 : 6
# 0.0037458620519744273
# 목표 지점까지 걸린 단계 수 : 4
# 0.0037142592050855155
# 목표 지점까지 걸린 단계 수 : 4
# 0.010356708696746361
# 목표 지점까지 걸린 단계 수 : 8
# 0.003727224333718096
# 목표 지점까지 걸린 단계 수 : 4
# 0.0036958497103304136
# 목표 지점까지 걸린 단계 수 : 4
# 0.0036648557278088703
# 목표 지점까지 걸린 단계 수 : 4
# 0.003634236457873738
# 목표 지점까지 걸린 단계 수 : 4
# 0.0036039860831387216
# 목표 지점까지 걸린 단계 수 : 4
# 0.003574098894728442
# 목표 지점까지 걸린 단계 수 : 4
# 0.011494630648618796
# 목표 지점까지 걸린 단계 수 : 6
# 0.008176224796628676
# 목표 지점까지 걸린 단계 수 : 8
# 0.003591332166413559
# 목표 지점까지 걸린 단계 수 : 4
# 0.0035616845724865814
# 목표 지점까지 걸린 단계 수 : 4
# 0.005923390288619615
# 목표 지점까지 걸린 단계 수 : 6
# 0.003547261712462481
# 목표 지점까지 걸린 단계 수 : 4
# 0.003518167021403895
# 목표 지점까지 걸린 단계 수 : 4
# 0.0034894161088357273
# 목표 지점까지 걸린 단계 수 : 4
# 0.00346100375941074
# 목표 지점까지 걸린 단계 수 : 4
# 0.003432924852903009
# 목표 지점까지 걸린 단계 수 : 4
# 0.0034051743622198274
# 목표 지점까지 걸린 단계 수 : 4
# 0.003377747351450598
# 목표 지점까지 걸린 단계 수 : 4
# 0.0033506389739659803
# 목표 지점까지 걸린 단계 수 : 4
# 0.005775007398719528
# 목표 지점까지 걸린 단계 수 : 6
# 0.003339749763134718
# 목표 지점까지 걸린 단계 수 : 4
# 0.01343608484273913
# 목표 지점까지 걸린 단계 수 : 14
# 0.00339157469309153
# 목표 지점까지 걸린 단계 수 : 4
# 0.0033642827319097512
# 목표 지점까지 걸린 단계 수 : 4
# 0.007138089180681838
# 목표 지점까지 걸린 단계 수 : 6
# 0.007221824446712113
# 목표 지점까지 걸린 단계 수 : 6
# 0.0033866980704144248
# 목표 지점까지 걸린 단계 수 : 4
# 0.007198493717525442
# 목표 지점까지 걸린 단계 수 : 6
# 0.005811938231784532
# 목표 지점까지 걸린 단계 수 : 6
# 0.00788428063716904
# 목표 지점까지 걸린 단계 수 : 10
# 0.003464884112657378
# 목표 지점까지 걸린 단계 수 : 4
# 0.0034366099291014973
# 목표 지점까지 걸린 단계 수 : 4
# 0.0034086689629318698
# 목표 지점까지 걸린 단계 수 : 4
# 0.003381056162536221
# 목표 지점까지 걸린 단계 수 : 4
# 0.005850565014209004
# 목표 지점까지 걸린 단계 수 : 6
# 0.003374576884913348
# 목표 지점까지 걸린 단계 수 : 4
# 0.01116347565230607
# 목표 지점까지 걸린 단계 수 : 6
# 0.00335229525024857
# 목표 지점까지 걸린 단계 수 : 4
# 0.008198179340160129
# 목표 지점까지 걸린 단계 수 : 8
# 0.0033717333738429306
# 목표 지점까지 걸린 단계 수 : 4
# 0.0033446793103430322
# 목표 지점까지 걸린 단계 수 : 4
# 0.007175652729062849
# 목표 지점까지 걸린 단계 수 : 6
# 0.005766356264840275
# 목표 지점까지 걸린 단계 수 : 6
# 0.00713913161799648
# 목표 지점까지 걸린 단계 수 : 6
# 0.0033820322473181313
# 목표 지점까지 걸린 단계 수 : 4
# 0.003354809157672445
# 목표 지점까지 걸린 단계 수 : 4
# 0.007129468515550318
# 목표 지점까지 걸린 단계 수 : 6
# 0.007863185556621445
# 목표 지점까지 걸린 단계 수 : 10
# 0.00726619351826184
# 목표 지점까지 걸린 단계 수 : 6
# 0.0034467825873214994
# 목표 지점까지 걸린 단계 수 : 4
# 0.0034186665218005965
# 목표 지점까지 걸린 단계 수 : 4
# 0.003390881831398601
# 목표 지점까지 걸린 단계 수 : 4
# 0.003363423491885481
# 목표 지점까지 걸린 단계 수 : 4
# 0.005873081864415222
# 목표 지점까지 걸린 단계 수 : 6
# 0.011068804462157217
# 목표 지점까지 걸린 단계 수 : 6
# 0.0033621640537237485
# 목표 지점까지 걸린 단계 수 : 4
# 0.00713690696620381
# 목표 지점까지 걸린 단계 수 : 6
# 0.0033564455594985512
# 목표 지점까지 걸린 단계 수 : 4
# 0.003329461509075711
# 목표 지점까지 걸린 단계 수 : 4
# 0.006919002833668343
# 목표 지점까지 걸린 단계 수 : 8
# 0.0033448329299366475
# 목표 지점까지 걸린 단계 수 : 4
# 0.005863303590476404
# 목표 지점까지 걸린 단계 수 : 6
# 0.0033400512236107585
# 목표 지점까지 걸린 단계 수 : 4
# 0.007118399625893258
# 목표 지점까지 걸린 단계 수 : 6
# 0.00333980102718711
# 목표 지점까지 걸린 단계 수 : 4
# 0.012118921702270039
# 목표 지점까지 걸린 단계 수 : 12
# 0.0033150688008327933
# 목표 지점까지 걸린 단계 수 : 4
# 0.003288570911201036
# 목표 지점까지 걸린 단계 수 : 4
# 0.010477686994952315
# 목표 지점까지 걸린 단계 수 : 14
# 0.0032787996902035807
# 목표 지점까지 걸린 단계 수 : 4
# 0.007058349246676449
# 목표 지점까지 걸린 단계 수 : 6
# 0.003274497437296138
# 목표 지점까지 걸린 단계 수 : 4
# 0.003248480035219499
# 목표 지점까지 걸린 단계 수 : 4
# 0.0032227613331268154
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031973369166326607
# 목표 지점까지 걸린 단계 수 : 4
# 0.003172202450004151
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031473536745462716
# 목표 지점까지 걸린 단계 수 : 4
# 0.00312278640701958
# 목표 지점까지 걸린 단계 수 : 4
# 0.006898851342394936
# 목표 지점까지 걸린 단계 수 : 6
# 0.003121379681478617
# 목표 지점까지 걸린 단계 수 : 4
# 0.0030970743518990707
# 목표 지점까지 걸린 단계 수 : 4
# 0.003073043049001932
# 목표 지점까지 걸린 단계 수 : 4
# 0.0030492817874954933
# 목표 지점까지 걸린 단계 수 : 4
# 0.0068380658844442235
# 목표 지점까지 걸린 단계 수 : 6
# 0.0030499304124068094
# 목표 지점까지 걸린 단계 수 : 4
# 0.0030263896262781864
# 목표 지점까지 걸린 단계 수 : 4
# 0.011662320313617087
# 목표 지점까지 걸린 단계 수 : 8
# 0.0054880662700485874
# 목표 지점까지 걸린 단계 수 : 6
# 0.006871989657763242
# 목표 지점까지 걸린 단계 수 : 6
# 0.0030761908511255515
# 목표 지점까지 걸린 단계 수 : 4
# 0.003052362653330948
# 목표 지점까지 걸린 단계 수 : 4
# 0.006871452736970915
# 목표 지점까지 걸린 단계 수 : 6
# 0.0030547218653208114
# 목표 지점까지 걸린 단계 수 : 4
# 0.0030310863144938915
# 목표 지점까지 걸린 단계 수 : 4
# 0.003007716254297306
# 목표 지점까지 걸린 단계 수 : 4
# 0.002984607828248456
# 목표 지점까지 걸린 단계 수 : 4
# 0.00550907991626981
# 목표 지점까지 걸린 단계 수 : 6
# 0.0029812602318181267
# 목표 지점까지 걸린 단계 수 : 4
# 0.0029584727260924537
# 목표 지점까지 걸린 단계 수 : 4
# 0.006671024988740039
# 목표 지점까지 걸린 단계 수 : 6
# 0.0029585352351476427
# 목표 지점까지 걸린 단계 수 : 4
# 0.002935977080623667
# 목표 지점까지 걸린 단계 수 : 4
# 0.002913668694640492
# 목표 지점까지 걸린 단계 수 : 4
# 0.006701976864085371
# 목표 지점까지 걸린 단계 수 : 6
# 0.006740928002067617
# 목표 지점까지 걸린 단계 수 : 8
# 0.0029590176046118064
# 목표 지점까지 걸린 단계 수 : 4
# 0.007601922360766747
# 목표 지점까지 걸린 단계 수 : 8
# 0.006859096778820475
# 목표 지점까지 걸린 단계 수 : 6
# 0.003000795862690697
# 목표 지점까지 걸린 단계 수 : 4
# 0.00688826690110516
# 목표 지점까지 걸린 단계 수 : 6
# 0.006945705283532465
# 목표 지점까지 걸린 단계 수 : 6
# 0.007002422930497354
# 목표 지점까지 걸린 단계 수 : 6
# 0.0030681069315344686
# 목표 지점까지 걸린 단계 수 : 4
# 0.0070297005524201026
# 목표 지점까지 걸린 단계 수 : 6
# 0.010649200733230474
# 목표 지점까지 걸린 단계 수 : 8
# 0.010275856305963851
# 목표 지점까지 걸린 단계 수 : 8
# 0.008570547890807682
# 목표 지점까지 걸린 단계 수 : 10
# 0.003233599865384275
# 목표 지점까지 걸린 단계 수 : 4
# 0.0032074109111008414
# 목표 지점까지 걸린 단계 수 : 4
# 0.003181532322298404
# 목표 지점까지 걸린 단계 수 : 4
# 0.007208365189124044
# 목표 지점까지 걸린 단계 수 : 6
# 0.0031928797479705215
# 목표 지점까지 걸린 단계 수 : 4
# 0.007070053774422276
# 목표 지점까지 걸린 단계 수 : 8
# 0.007006067370597814
# 목표 지점까지 걸린 단계 수 : 6
# 0.0032313797281316448
# 목표 지점까지 걸린 단계 수 : 4
# 0.0032050925932880295
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031791189856818503
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031534540405766254
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031280929847879654
# 목표 지점까지 걸린 단계 수 : 4
# 0.0071521507397067224
# 목표 지점까지 걸린 단계 수 : 6
# 0.007204997679621947
# 목표 지점까지 걸린 단계 수 : 6
# 0.0031799741211054333
# 목표 지점까지 걸린 단계 수 : 4
# 0.003154058210395938
# 목표 지점까지 걸린 단계 수 : 4
# 0.007164654377470797
# 목표 지점까지 걸린 단계 수 : 8
# 0.0031833366094880175
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031573317119757555
# 목표 지점까지 걸린 단계 수 : 4
# 0.007214819206026242
# 목표 지점까지 걸린 단계 수 : 6
# 0.0031726468994948687
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031466395477805983
# 목표 지점까지 걸린 단계 수 : 4
# 0.007578286386474523
# 목표 지점까지 걸린 단계 수 : 10
# 0.0031823777240072015
# 목표 지점까지 걸린 단계 수 : 4
# 0.005457950651007605
# 목표 지점까지 걸린 단계 수 : 6
# 0.0031674936023326147
# 목표 지점까지 걸린 단계 수 : 4
# 0.007086142969254618
# 목표 지점까지 걸린 단계 수 : 8
# 0.0031943524518589783
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031680842290154887
# 목표 지점까지 걸린 단계 수 : 4
# 0.0031421349518417838
# 목표 지점까지 걸린 단계 수 : 4
# 0.003116499562211772
# 목표 지점까지 걸린 단계 수 : 4
# 0.005443167926179597
# 목표 지점까지 걸린 단계 수 : 6
# 0.003103590125492349
# 목표 지점까지 걸린 단계 수 : 4
# 0.003078474802603426
# 목표 지점까지 걸린 단계 수 : 4
# 0.0030536593766521056
# 목표 지점까지 걸린 단계 수 : 4
# 0.006741674604355097
# 목표 지점까지 걸린 단계 수 : 6
# 0.0030405360216333097
# 목표 지점까지 걸린 단계 수 : 4
# 0.005402087426093792
# 목표 지점까지 걸린 단계 수 : 6
# 0.00302943336473125
# 목표 지점까지 걸린 단계 수 : 4
# 0.007090641970128958
# 목표 지점까지 걸린 단계 수 : 6
# 0.0030439075948481276
# 목표 지점까지 걸린 단계 수 : 4
# 0.003019488748504058
# 목표 지점까지 걸린 단계 수 : 4
# 0.0029953590090780746
# 목표 지점까지 걸린 단계 수 : 4
# 0.007061059699687858
# 목표 지점까지 걸린 단계 수 : 6
# 0.007603508468064901
# 목표 지점까지 걸린 단계 수 : 8
# 0.00716344584527525
# 목표 지점까지 걸린 단계 수 : 6
# 0.003104161153079321
# 목표 지점까지 걸린 단계 수 : 4
# 0.00307870685787736
# 목표 지점까지 걸린 단계 수 : 4
# 0.0030535621642669847
# 목표 지점까지 걸린 단계 수 : 4
# 0.003028722140373745
# 목표 지점까지 걸린 단계 수 : 4
# 0.003004181949789256
# 목표 지점까지 걸린 단계 수 : 4
# 0.002979936849443955
# 목표 지점까지 걸린 단계 수 : 4
# 0.0029559821875383904
# 목표 지점까지 걸린 단계 수 : 4
# 0.0070255960264838935
# 목표 지점까지 걸린 단계 수 : 6
# 0.0029743391420189655
# 목표 지점까지 걸린 단계 수 : 4
# 0.002950320084805051
# 목표 지점까지 걸린 단계 수 : 4
# 0.0029265896859211257
# 목표 지점까지 걸린 단계 수 : 4
# 0.002903143389214824
# 목표 지점까지 걸린 단계 수 : 4
# 0.0028799767261369416
# 목표 지점까지 걸린 단계 수 : 4
# 0.010224586803584151
# 목표 지점까지 걸린 단계 수 : 6
# 0.010224703253768196
# 목표 지점까지 걸린 단계 수 : 6
# 0.002858480782733687
# 목표 지점까지 걸린 단계 수 : 4
# 0.002835987581253245
# 목표 지점까지 걸린 단계 수 : 4
# 0.00688309711110785
# 목표 지점까지 걸린 단계 수 : 6
# 0.007365382390425154
# 목표 지점까지 걸린 단계 수 : 8
# 0.002881362438873665
# 목표 지점까지 걸린 단계 수 : 4
# 0.0028585657713914026
# 목표 지점까지 걸린 단계 수 : 4
# 0.002836037535935816
# 목표 지점까지 걸린 단계 수 : 4
# 0.002813773574891605
# 목표 지점까지 걸린 단계 수 : 4
# 0.0027917698093004456
# 목표 지점까지 걸린 단계 수 : 4
# 0.005182338080988197
# 목표 지점까지 걸린 단계 수 : 6
# 0.0027842397843833022
# 목표 지점까지 걸린 단계 수 : 4
# 0.0027626393599152407
# 목표 지점까지 걸린 단계 수 : 4
# 0.0027412881042635506
# 목표 지점까지 걸린 단계 수 : 4
# 0.0063361293936346
# 목표 지점까지 걸린 단계 수 : 6
# 0.002731147425191968
# 목표 지점까지 걸린 단계 수 : 4
# 0.002710209987688686
# 목표 지점까지 걸린 단계 수 : 4
# 0.002689510913317719
# 목표 지점까지 걸린 단계 수 : 4
# 0.006697009036749357
# 목표 지점까지 걸린 단계 수 : 6
# 0.006356722164414623
# 목표 지점까지 걸린 단계 수 : 6
# 0.007250644519426669
# 목표 지점까지 걸린 단계 수 : 8
# 0.006773095897470022
# 목표 지점까지 걸린 단계 수 : 6
# 0.0027863001049119526
# 목표 지점까지 걸린 단계 수 : 4
# 0.002764628151385694
# 목표 지점까지 걸린 단계 수 : 4
# 0.006459159417189116
# 목표 지점까지 걸린 단계 수 : 6
# 0.002756516511913866
# 목표 지점까지 걸린 단계 수 : 4
# 0.002735232646882829
# 목표 지점까지 걸린 단계 수 : 4
# 0.002714192776557378
# 목표 지점까지 걸린 단계 수 : 4
# 0.005096828539627535
# 목표 지점까지 걸린 단계 수 : 6
# 0.002707208286273098
# 목표 지점까지 걸린 단계 수 : 4
# 0.002686544395713357
# 목표 지점까지 걸린 단계 수 : 4
# 0.005043713454161519
# 목표 지점까지 걸린 단계 수 : 6
# 0.0026778888144206314
# 목표 지점까지 걸린 단계 수 : 4
# 0.00265760480390366
# 목표 지점까지 걸린 단계 수 : 4
# ...
# 0.0001310999809668624
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013086925218989097
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013063913869778947
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013040963828163214
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013018074874517407
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012995246790075896
# 목표 지점까지 걸린 단계 수 : 4
# 0.0013862697684182152
# 목표 지점까지 걸린 단계 수 : 6
# 0.00013215822515443357
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013192384667153924
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013169009941327824
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013145698108757604
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013122448941418376
# 목표 지점까지 걸린 단계 수 : 4
# 0.0010010904582555338
# 목표 지점까지 걸린 단계 수 : 6
# 0.00013203217373867863
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013179894898739802
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013156634891289647
# 목표 지점까지 걸린 단계 수 : 4
# 0.001026291192115867
# 목표 지점까지 걸린 단계 수 : 6
# 0.00013244946355941284
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013221588877042854
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013198293761909792
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013175060786601092
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013151889728133317
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013128780364625448
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013105732475118988
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013082745839721605
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001305982023933703
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013036955456194148
# 목표 지점까지 걸린 단계 수 : 4
# 0.00013014151273151899
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001299140747434875
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012968723844598677
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012946100169916076
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001292353623719624
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012901031834221081
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001287858674982635
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012856200773695044
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012833873696590017
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012811605310018848
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012789395406579557
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012767243779677855
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012745150223733397
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001272311453402314
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012701136506698685
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001267921593895438
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012657352628698063
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001263554637486574
# 목표 지점까지 걸린 단계 수 : 4
# 0.00120354183549559
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012812078842702745
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012789852626237871
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012767684766790827
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012745575058296238
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001272352329583313
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012701529275146312
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012679592793135921
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012657713647315494
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012635891636360135
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012614126559674053
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012592418217643314
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012570766411421248
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012549170943160215
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012527631615822862
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012506148233215955
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012484720600033396
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012463348521867847
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012442031805131107
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012420770257075102
# 목표 지점까지 걸린 단계 수 : 4
# 0.0013496921721784724
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012631082384267737
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012609253052827535
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012587480940210068
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012565765844505666
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012544107564509133
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012522505900047602
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001250096065185339
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012479471621408902
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012458038611157587
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012436661424511386
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001241533986550622
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012394073739339234
# 목표 지점까지 걸린 단계 수 : 4
# 0.000123728628518633
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001235170700981461
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012330606020916936
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001230955969355966
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012288567837035608
# 목표 지점까지 걸린 단계 수 : 4
# 0.000122676302615813
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012246746778179878
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001222591719854879
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012205141335450143
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012184419002223175
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001216375001332707
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012143134183617565
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012122571329244852
# 목표 지점까지 걸린 단계 수 : 4
# 0.0013538503677864421
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012337636763799266
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012316484963737113
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001229538829822848
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012274346573209333
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012253359595549435
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012232427172980537
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001221154911401432
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012190725228065392
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012169955325468974
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012149239217192596
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012128576715232306
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012107967632373103
# 목표 지점까지 걸린 단계 수 : 4
# 0.0011737869396152307
# 목표 지점까지 걸린 단계 수 : 6
# 0.0001227539207654775
# 목표 지점까지 걸린 단계 수 : 4
# 0.0012001774546757833
# 목표 지점까지 걸린 단계 수 : 6
# 0.0001245158894013238
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012430122908172782
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012408713103686554
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001238735932819028
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001236606138405004
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012344819074443236
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012323632203420712
# 목표 지점까지 걸린 단계 수 : 4
# 0.004338318640717048
# 목표 지점까지 걸린 단계 수 : 6
# 0.004330466745565932
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012532668805109032
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012511127101346407
# 목표 지점까지 걸린 단계 수 : 4
# 0.000124896414868075
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001246821176516845
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012446837740766846
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012425519218874602
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012404256005671063
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012383047908080813
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001236189473399693
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012340796292067795
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012319752391827532
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012298762843573723
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012277827458562207
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012256946048759022
# 목표 지점까지 걸린 단계 수 : 4
# 0.000122361184269653
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012215344406945293
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012194623803014198
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012173956430514173
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012153342105489066
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012132780644891206
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012112271866261334
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012091815588136101
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012071411629767555
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012051059811212135
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012030759953168997
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012010511877377089
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011990315406056572
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011970170362373897
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011950076570331654
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011930033854423532
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011910042040048224
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011890100953544126
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011870210421649312
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011850370272042075
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011830580333119234
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011810840434041403
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011791150404548423
# 목표 지점까지 걸린 단계 수 : 4
# 0.0011826239333162687
# 목표 지점까지 걸린 단계 수 : 6
# 0.00011963318341903784
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001194322310195204
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011923178979619115
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011903185800281324
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011883243389660368
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001186335157462165
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011843510182482815
# 목표 지점까지 걸린 단계 수 : 4
# 0.000958971284973905
# 목표 지점까지 걸린 단계 수 : 6
# 0.00011922712657138138
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011902786391262618
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011882910483055308
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011863084761699547
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011843309057029197
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011823583199406171
# 목표 지점까지 걸린 단계 수 : 4
# 0.0013058472658202327
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012020562612728714
# 목표 지점까지 걸린 단계 수 : 4
# 0.0009832284120287558
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012104952448961301
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012084562743156987
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012064225002669272
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001204393904929834
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012023704705914177
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012003521795912395
# 목표 지점까지 걸린 단계 수 : 4
# 0.0012057075901753048
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012175549900009588
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012154961094821247
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012134424974054488
# 목표 지점까지 걸린 단계 수 : 4
# 0.001230561994833075
# 목표 지점까지 걸린 단계 수 : 6
# 0.00012315021994711156
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012294047561292772
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012273127208509496
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001225226074891162
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001223144799598081
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012210688763875967
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012189982867660473
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012169330123099585
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012148730346887501
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012128183356401208
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012107688969854001
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012087247006267385
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001206685728544557
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012046519627884229
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001202623385501457
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012005999788838526
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011985817252332595
# 목표 지점까지 걸린 단계 수 : 4
# 0.004121463287213498
# 목표 지점까지 걸린 단계 수 : 8
# 0.00012221649022446483
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012200918622188445
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012180241460467943
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012159617353586435
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012139046118521228
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012118527573029038
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012098061535603145
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012077647825697348
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012057286263416657
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012036976669611843
# 목표 지점까지 걸린 단계 수 : 4
# 0.00012016718866031742
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011996512675136427
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011976357920098941
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011956254424948069
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001193620201436589
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001191620051389404
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011896249749802565
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011876349548965368
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011856499739287991
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011836700149125794
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011816950607668186
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011797250944957545
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011777600991542785
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011758000578894132
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001173844953908914
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011718947704962915
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011699494910073077
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011680090988607124
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001166073577555226
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011641429106500241
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001162217081796691
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011602960746819914
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011583798730878912
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011564684608519372
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011545618218882815
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001152659940173266
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011507627997568541
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011488703847519453
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011469826793351033
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001145099667755247
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011432213343210047
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011413476634291979
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011394786395042995
# 목표 지점까지 걸린 단계 수 : 4
# 0.004079681928125878
# 목표 지점까지 걸린 단계 수 : 8
# 0.00011626546952601784
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011607321699661985
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011588144578796727
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011569015427835214
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011549934085532815
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011530900391120737
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011511914184617576
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011492975306721422
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011474083598777586
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011455238902701413
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011436441061293302
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001141768991782411
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011398985316352431
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011380327101464041
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011361715118515109
# 목표 지점까지 걸린 단계 수 : 4
# 0.0042205889651621455
# 목표 지점까지 걸린 단계 수 : 6
# 0.00011459328333749026
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011440571769123775
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011421861611811239
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011403197707586694
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001138457990280551
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011366008044628312
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011347481980688266
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011329001559374531
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011310566629611427
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011292177041059316
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011273832643923093
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011255533288988782
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011237278827827372
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011219069112441103
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011200903995569472
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011182783330536752
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011164706971203246
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011146674772131125
# 목표 지점까지 걸린 단계 수 : 4
# 0.0009434023446335642
# 목표 지점까지 걸린 단계 수 : 6
# 0.00011226560151286584
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011208433099779008
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011190350220091107
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011172311367602453
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011154316398653309
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011136365169958813
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011118457538897633
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001110059336349948
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011082772502192008
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011064994814165632
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011047260159036641
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011029568397186683
# 목표 지점까지 걸린 단계 수 : 4
# 0.00011011919389316248
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010994312996923453
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010976749081970452
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010959227506911542
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010941748134900287
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010924310829567643
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010906915455123449
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010889561876275926
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010872249958370633
# 목표 지점까지 걸린 단계 수 : 4
# 0.000108549795672307
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001083775056922899
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010820562831324182
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001080341622095183
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010786310606144926
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010769245855375004
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010752221837761859
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010735238422884645
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010718295480873635
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010701392882279254
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010684530498373569
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010667708200776636
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001065092586161661
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010634183353753178
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010617480550204582
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010600817324811843
# 목표 지점까지 걸린 단계 수 : 4
# 0.0009442517540575891
# 목표 지점까지 걸린 단계 수 : 6
# 0.00010685052727941145
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010668276167160803
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010651539288919487
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010634841967524337
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010618184077678533
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010601565494581557
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010584986094076473
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010568445752355896
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010551944346129556
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010535481752670627
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010519057849644672
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010502672515240452
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010486325628073986
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001047001706747687
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010453746712825278
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010437514444457986
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010421320142723137
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010405163688856703
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010389044964247661
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010372963850901508
# 목표 지점까지 걸린 단계 수 : 4
# 0.001210896074189725
# 목표 지점까지 걸린 단계 수 : 6
# 0.00010545552687883132
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010529050030690448
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001051258636362365
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010496161562871704
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010479775505359279
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010463428068379146
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010447119129700089
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010430848567570886
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010414616260866205
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010398422088715199
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010382265930964675
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010366147667721821
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010350067179710001
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010334024348140208
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001031801905455286
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010302051181017464
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010286120610173213
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010270227225101479
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010254370909121638
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010238551546266732
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010222769020912584
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010207023217981975
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010191314022696234
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001017564132088887
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001016000499868084
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010144404942821934
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010128841040346441
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010113313178808717
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010097821246241381
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010082365130977856
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001006694472190997
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010051559908340335
# 목표 지점까지 걸린 단계 수 : 4
# 0.0001003621058002762
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010020896627024704
# 목표 지점까지 걸린 단계 수 : 4
# 0.00010005617939963171
# 목표 지점까지 걸린 단계 수 : 4
# 9.990374409856763e-05
# 목표 지점까지 걸린 단계 수 : 4

# %%
# 학습이 끝난 정책 확인
np.set_printoptions(precision = 3, suppress=True) # precision : 유효 자리수, suppress : 지수 표시 여부
print(pi)
# Out:
# [[0.    0.013 0.987 0.   ]
#  [0.    0.255 0.    0.745]
#  [0.    0.    0.426 0.574]
#  [0.011 0.978 0.011 0.   ]
#  [0.    0.    0.982 0.018]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.013 0.987 0.    0.   ]]

# %%
fig = plt.figure(figsize=(5,5))
ax = plt.gca()

# 붉은 벽
plt.plot([1,1], [0,1], color='red', linewidth=2)
plt.plot([1,2], [2,2], color='red', linewidth=2)
plt.plot([2,2], [2,1], color='red', linewidth=2)
plt.plot([2,3], [1,1], color='red', linewidth=2)

# 각 state 표현
plt.text(0.5, 2.5, 's0', size=14, ha ='center')
plt.text(1.5, 2.5, 's1', size=14, ha ='center')
plt.text(2.5, 2.5, 's2', size=14, ha ='center')
plt.text(0.5, 1.5, 's3', size=14, ha ='center')
plt.text(1.5, 1.5, 's4', size=14, ha ='center')
plt.text(2.5, 1.5, 's5', size=14, ha ='center')
plt.text(0.5, 0.5, 's6', size=14, ha ='center')
plt.text(1.5, 0.5, 's7', size=14, ha ='center')
plt.text(2.5, 0.5, 's8', size=14, ha ='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림 범위 및 눈금 제거
ax.set_xlim(0.0,3.0)
ax.set_ylim(0.0,3.0)
plt.tick_params(axis='both',which='both', bottom=False, top=False,
               labelbottom=False, right=False, left=False, labelleft=False)

# agent(원)
line, = ax.plot([0.5],[2.5], marker="o",color='g', markersize=60)

# %%
# agent의 이동 시각화
from matplotlib import animation
from IPython.display import HTML

def init():
    '''배경 이미지 초기화'''
    line.set_data([],[])
    return (line,)

def animate(i):
    '''프레임 단위로 이미지 생성'''
    state = s_a_history[i][0]
    x = (state % 3) + 0.5 # x 좌표
    y = 2.5 - int(state/3) # y 좌표
    line.set_data(x,y)
    return (line, )

anim = animation.FuncAnimation(fig, animate, init_func=init,
                              frames = len(s_a_history),
                              interval = 200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgdcdd21b06df8422e9d1975484e33392f">
#     <br>
#     <input id="_anim_sliderdcdd21b06df8422e9d1975484e33392f" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animdcdd21b06df8422e9d1975484e33392f.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animdcdd21b06df8422e9d1975484e33392f.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectdcdd21b06df8422e9d1975484e33392f" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdcdd21b06df8422e9d1975484e33392f";
#     var slider_id = "_anim_sliderdcdd21b06df8422e9d1975484e33392f";
#     var loop_select_id = "_anim_loop_selectdcdd21b06df8422e9d1975484e33392f";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAG81JREFUeJzt3X1wVfWdx/HPvXkkCVholELAIHZq\
# Fos8JEQBJYiuFKikKjAW2hLiIDLYitCKdVrHcW2rDLAtlba6lUipsFWoYtXGbYGER4UAQSGwaIGA\
# PFiguiEETG7y2z8uyfCUJ0hyvvfe92smQ5Oc3PvNr/Gdk5OTc3zOOScAgDl+rwcAAFwagQYAowg0\
# ABhFoAHAKAINAEYRaAAwikADgFEEGgCMItAAYBSBBgCjCDQAGEWgAcAoAg0ARhFoADCKQAOAUQQa\
# AIwi0ABgFIEGAKMINAAYRaABwCgCDQBGEWgAMIpAA4BRBBoAjCLQAGAUgQYAowg0ABhFoAHAKAIN\
# AEYRaAAwikADgFEEGgCMItAAYBSBBgCjCDQAGEWgAcAoAg0ARhFoADCKQAOAUQQaAIwi0ABgFIEG\
# AKOivR7gciQnJ6tHjx5ejwEgzOzfv1/Hjx/3eow6IRnoHj16qKioyOsxAISZjIwMr0c4D4c4AMAo\
# Ag0ARhFoADCKQAOAUQQaAIwi0ABgFIEGAKMINAAYRaABwCgCDQBGEWgAMIpAA4BRBBoAjCLQAGBU\
# SF5u1DLnnA6dPKQth7do06FNKiwtVMmxEp0OnFagJqDqmmpF+aMU7Y9Wu+h26nV1L2WlZikzJVPp\
# XdOV0j5FPp/P608DgAEEugXUuBqt3LtS896bp/UH1itQE1BMVIzKK8tV42ou2j5QE1CgJqAzgTNa\
# f3C9Nn6yUUmxSaqsrlSMP0aDrx2sGbfM0B0975Dfxw85QKQi0Ffgs9OfaeG2hZq7ca5OVp5UeWV5\
# 3ftOB043+XFqXI3KviiTJJ3RGeV/nK91B9apfWx7zRw4U7n9ctWxXccWnx+AbeyeXYZPyj7R+OXj\
# 1XVeVz1Z8KSOlB85L84tobyyXEfKj+jJgifVdV5XTVg+QZ+UfdKizwHANgLdDM45vbTtJaU9n6bX\
# dr6mM4EzqqiqaNXnrKiq0JnAGb2681WlPZ+ml7a9JOdcqz4nABsIdBMdKjuk2xfdrkf++ohOVZ1S\
# wAXa9PkDLqBTVaf0yF8f0e2LbtehskNt+vwA2h6BboK84jylPZ+m9QfX61TVKU9nOVV1SusPrlfa\
# gjTlFed5OguA1kWgG+Cc06P5j+rhdx5WeVW5AjVtu9dcn0BNQOWV5Xr4nYc1490ZHPIAwhSBrkd1\
# TbVy3sjRi1tfbPXjzJeroqpCL2x5QZNWTFJ1TbXX4wBoYZxmdwnOOeWuyNWyXcvMxrlWRVWFXit5\
# TZKUl53HH7kAYYQ96EuY8e4MLd+13Hyca9VGeub/zPR6FAAtiEBfIK84Ty9ufdHzXwY2V+3hDn5x\
# CIQPAn2OQ2WH9IN3fhAye84Xqqiq0A/++gNOwQPCBIE+yzmn8X8erzPVZ7we5Yp8EfhCE/48gTM7\
# gDBAoM9aWLxQWw5vMXMq3eWqqqlS0eEiDnUAYYBAK3htjdq/EAwHp6pO6ZH8RzjUAYQ4Ai3psb89\
# pi8CX3g9Ros6Ezijx/72mNdjALgCER/oz05/ptd3v97m19ZobYGagP68+8/67PRnXo8C4DJFfKAX\
# blsYthfF9/v8HIsGQlh4lqmJalyN5m6c27an1X0qKU/SM5LmSiqQ1EonXFRUVWjuhrmXvKtLpDhz\
# 5oxycnJ00003KSYmRkOHDvV6pLBXUFCg7OxsdenSRQkJCbrpppu0cOFCr8cKSREd6JV7V+pk5cm2\
# e8Izkv4gKVHSZEnfkLRB0sbWe8qyyjKt2req9Z7AuOrqasXHx+vhhx/WqFGjvB4nImzYsEG9e/fW\
# smXLtGPHDk2dOlUPPviglixZ4vVoISeiAz3vvXktficUSdJ+Sf8l6WeSfiHpRQX3n
