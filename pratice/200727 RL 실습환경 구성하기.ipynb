# %% [markdown]
# 자주 쓰던 코랩, 주피터 환경에서 강화학습을 구현하려고 하니 무슨 제약이 그렇게 많은지.. 파이참으로 하려고 하다가 계속 초보자의 변화의 두려움? 때문에 미루다가, 이번에야말로 업그레이드를 시키려고 마음을 단단히 먹었다. 이번 주는 dueling DQN, PER도 보고, 음성처리 수업도 보고, 파이썬 고급 함수도 공부하자! (개많넹ㅎㅎ)

# %% [markdown]
# 과감하게 모두연 강화학습 스터디(그것도 최상 난이도)를 도전하고 첫 주에 발표를 하고 엄청 깨질 줄 알았는데, 자상하신 분들께서 쿨하게 이해해주신 것 같다. 부족함을 너무나도 많이 느꼈다. 퍼실 분과 얘기를 해 봤는데 코랩은 환경 구성이 어렵고, 주피터는 가능하다고 하셨다. 그 분은 `VScode`로 하신다고 했다. 짱짱 에디터인 듯 해서 나도 이용해보려고 한다.

# %% [markdown]
# 우선 `anaconda prompt`를 이용해서 필요한 것들을 설치해야 한다.<br>
# 1. `conda create -n 새로운환경이름 python=3.x`을 통해 새로운 환경을 생성한다. <br>
# (가상환경을 활성화려면 `conda activate env_name`, 비활성화하려면 `conda deactivate` 해준다.)<br>
# 2. 필요한 환경들 설치(pythorch, tensorflow, tensorboardX, Gym 등등) `pip install 환경`이렇게 설치 해주면 된다.

# %% [markdown]
# 이제 기본적인 설정은 끝났다. VSCode를 실행해서 경로를 맞춰보겠다!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (https://github.com/dongminlee94/Samsung-DRL-Code)를 참고하였다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 원하는 환경을 실행시키기 위해서는 `ctrl + ~`로 terminal 창을 띄운 다음, **select default shell**을 눌러 **command prompt**로 바꿔준다.

# %% [markdown]
# 왜 환경설정도 시켰고 시키는대로 했는데 `FileNotFoundError: Could not find module 'C:\Users\kgh67\anaconda3\envs\reinforce_jh\lib\site-packages\torch\lib\caffe2_nvrtc.dll' (or one of its dependencies). Try using the full path with constructor syntax.` 에러가 뜨는걸까.. 일단 수업이니 밤에 재도전!

# %% [markdown]
# #### 파이참, dscode 다 다시 설치해봐야지..

# %% [markdown]
# ### 결국 내가 한 건 주피터로 구현

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 어떻게 했냐! 는 이제 설명하겠다.<br>
# 1. anaconda prompt에서 필요한 환경 설정<br>
# 2. anaconda navigator에서 1 환경으로 변경<br>
# 3. 바뀐 환경으로 노트북 실행<br><br>
#
# 정말 간단했다 ㅎㅎ. VSCode는 다음 기회에
